# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pandas as pd
import random

from sklearn.model_selection import train_test_split

# %%
RANDOM_STATE = 42

torch.manual_seed(RANDOM_STATE)
torch.cuda.manual_seed_all(RANDOM_STATE)  # For multi-GPU.
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)


def _init_fn(worker_id):
    np.random.seed(int(RANDOM_STATE))

# %%
train = pd.read_csv('../data/train.csv', header=None, names=["text"])
test = pd.read_csv('../data/answers.csv', header=None, names=["text"])


def separate_xy(df, prefix="train"):
    df[prefix + "_X"] = df["text"].apply(lambda x: x[:-1])
    df[prefix + "_y"] = df["text"].apply(lambda x: x[-1])
    return df

train_df = separate_xy(train, 'train')
test_df = separate_xy(test, 'test')

# %%
train_df
# Out:
#            text   train_X train_y
# 0     SR2SR2SGR  SR2SR2SG       R
# 1     SRGSRSRSR  SRGSRSRS       R
# 2     KFKFKFKFK  KFKFKFKF       K
# 3     X2LS2FRS2  X2LS2FRS       2
# 4     MMMMGGGGG  MMMMGGGG       G
# ...         ...       ...     ...
# 2538  S2ZR22222  S2ZR2222       2
# 2539  62SNRM1MM  62SNRM1M       M
# 2540  ASSRSRSRS  ASSRSRSR       S
# 2541  2ZZT2Z2ZT  2ZZT2Z2Z       T
# 2542  22MMMZTSJ  22MMMZTS       J
#
# [2543 rows x 3 columns]

# %%
train_X, val_X, train_y, val_y = train_test_split(train_df["train_X"], train_df["train_y"], test_size=0.1, random_state=RANDOM_STATE)

# %%
vocab = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567'

id2char = {idx: char for idx, char in enumerate(vocab)}
char2id = {char: idx for idx, char in enumerate(vocab)}


# Define the size of the input (number of unique characters), hidden layer, and output (same as input)
input_size = len(vocab)
hidden_size = len(vocab) * 3
output_size = len(vocab)

# %%
# Define the RNN model
class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_hidden_layers=1, embedding_dim=10):
        super(SimpleLSTM, self).__init__()
        self.hidden_size = hidden_size

        # Embedding layer: 8 characters in the alphabet and embedding_dim can be a small number like 10
        self.embedding = nn.Embedding(input_size, embedding_dim=embedding_dim)
        
        # RNN layer
        self.lstm = nn.LSTM(input_size=embedding_dim, hidden_size=hidden_size, num_layers=num_hidden_layers, batch_first=True)

        # Output layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # Embedding input
        embedded = self.embedding(x)

        # RNN output
        lstm_out, _ = self.lstm(embedded)
        last_lstm_out = lstm_out[:, -1, :]

        # Fully connected layer output
        out = self.fc(last_lstm_out)
        return out

# %%
# Create the model
simple_rnn = SimpleLSTM(input_size, hidden_size, output_size)

# Define the loss function and the optimizer
# loss_function = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model_output = simple_rnn(torch.tensor([[18, 18, 18, 18]], dtype=torch.long))
model_output
# Out:
# tensor([[-0.0495,  0.1151,  0.0054, -0.0834, -0.1550,  0.0626, -0.0536, -0.0534,
#          -0.1277, -0.0916, -0.0663, -0.0305,  0.1157,  0.0140,  0.0426, -0.0071,
#          -0.0010,  0.0088,  0.0553,  0.0114, -0.0589,  0.0406, -0.0770, -0.0772,
#          -0.1052,  0.1195, -0.0918,  0.0785, -0.1174, -0.0656,  0.0600, -0.0671,
#          -0.1058]], grad_fn=<AddmmBackward0>)

# %%
probabilities = F.softmax(model_output, dim=1)
probabilities
# Out:
# tensor([[0.0294, 0.0347, 0.0311, 0.0284, 0.0265, 0.0329, 0.0293, 0.0293, 0.0272,
#          0.0282, 0.0289, 0.0300, 0.0347, 0.0314, 0.0323, 0.0307, 0.0309, 0.0312,
#          0.0327, 0.0313, 0.0292, 0.0322, 0.0286, 0.0286, 0.0278, 0.0348, 0.0282,
#          0.0334, 0.0275, 0.0290, 0.0328, 0.0289, 0.0278]],
#        grad_fn=<SoftmaxBackward0>)

# %%
id2char[int(probabilities.argmax())]
# Out:
# 'Z'

# %%
char2id['S']
# Out:
# 18

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CharSequenceDataset(Dataset):
    def __init__(self, sequences, labels):
        """
        Args:
            sequences (list of strings): List of character sequences.
            labels (list of strings): List of single characters (labels).
        """
        self.sequences = sequences
        self.labels = labels

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        # Convert the sequence and label to numeric format
        sequence = torch.tensor([char2id[char] for char in self.sequences[idx]], dtype=torch.long)
        label = torch.tensor(char2id[self.labels[idx]], dtype=torch.long)

        return sequence, label

# %%
train_X
# Out:
# 2240    2SR22SR2
# 678     M2SKKZEE
# 1194    S2LZTK2K
# 1572    2MSG2M2M
# 2276    EIVD12E1
#           ...
# 1638    1111SRER
# 1095    111R11SR
# 1130    SSGSRSRS
# 1294    MZTKE2XZ
# 860     22MSR1SE
# Name: train_X, Length: 2288, dtype: object

# %%
train_df["train_X"]
# Out:
# 0       SR2SR2SG
# 1       SRGSRSRS
# 2       KFKFKFKF
# 3       X2LS2FRS
# 4       MMMMGGGG
#           ...
# 2538    S2ZR2222
# 2539    62SNRM1M
# 2540    ASSRSRSR
# 2541    2ZZT2Z2Z
# 2542    22MMMZTS
# Name: train_X, Length: 2543, dtype: object

# %%
train_dataset = CharSequenceDataset(list(train_X), list(train_y))
# train_dataset = CharSequenceDataset(train_df["train_X"], train_df["train_y"])
val_dataset = CharSequenceDataset(list(val_X), list(val_y))
test_dataset = CharSequenceDataset(test_df["test_X"], test_df["test_y"])

train_dataset, val_dataset, test_dataset
# Out:
# (<__main__.CharSequenceDataset at 0x7f48d1b63ed0>,
#  <__main__.CharSequenceDataset at 0x7f48d18bfc50>,
#  <__main__.CharSequenceDataset at 0x7f48d18be550>)

# %%
# Define batch size
batch_size = 64

# Create the DataLoader for training data
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=_init_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=_init_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=_init_fn)

train_loader, val_loader, test_loader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f48d18bf910>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f48d18bded0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f48d18bda50>)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Best params: {'hidden_size': 128, 'learning_rate': 0.0002, 'embedding_dim': 50, 'num_hidden_layers': 1}
# Hyperparameters
hidden_size = 128
embedding_dim = 50
num_hidden_layers = 1
learning_rate = 0.0002
num_epochs = 70

model = SimpleLSTM(input_size, hidden_size, output_size, num_hidden_layers, embedding_dim)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
import torch

def train_model(model, train_loader, val_loader, num_epochs, criterion, optimizer, model_save_path):
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        for batch_idx, (data, targets) in enumerate(train_loader):
            # Forward pass
            scores = model(data)
            loss = criterion(scores, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data, targets in val_loader:
                scores = model(data)
                loss = criterion(scores, targets)
                val_loss += loss.item()

        val_loss /= len(val_loader)

        # Print training and validation loss
        print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        # Check if this is the best model so far and save it if it is
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)
            print(f"Saved model with validation loss: {best_val_loss:.4f}")

# Example usage
model_save_path = 'best_model.pth'  # Define your model save path
train_model(model, train_loader, val_loader, num_epochs, criterion, optimizer, model_save_path)
# Out:
# Epoch [1/70], Training Loss: 3.4038, Validation Loss: 3.2583
# Saved model with validation loss: 3.2583
# Epoch [2/70], Training Loss: 3.0020, Validation Loss: 2.7635
# Saved model with validation loss: 2.7635
# Epoch [3/70], Training Loss: 2.6640, Validation Loss: 2.5809
# Saved model with validation loss: 2.5809
# Epoch [4/70], Training Loss: 2.5420, Validation Loss: 2.4662
# Saved model with validation loss: 2.4662
# Epoch [5/70], Training Loss: 2.4559, Validation Loss: 2.3734
# Saved model with validation loss: 2.3734
# Epoch [6/70], Training Loss: 2.3853, Validation Loss: 2.3116
# Saved model with validation loss: 2.3116
# Epoch [7/70], Training Loss: 2.3286, Validation Loss: 2.2553
# Saved model with validation loss: 2.2553
# Epoch [8/70], Training Loss: 2.2782, Validation Loss: 2.2101
# Saved model with validation loss: 2.2101
# Epoch [9/70], Training Loss: 2.2357, Validation Loss: 2.1759
# Saved model with validation loss: 2.1759
# Epoch [10/70], Training Loss: 2.1931, Validation Loss: 2.1365
# Saved model with validation loss: 2.1365
# Epoch [11/70], Training Loss: 2.1578, Validation Loss: 2.1014
# Saved model with validation loss: 2.1014
# Epoch [12/70], Training Loss: 2.1237, Validation Loss: 2.0778
# Saved model with validation loss: 2.0778
# Epoch [13/70], Training Loss: 2.0930, Validation Loss: 2.0452
# Saved model with validation loss: 2.0452
# Epoch [14/70], Training Loss: 2.0661, Validation Loss: 2.0222
# Saved model with validation loss: 2.0222
# Epoch [15/70], Training Loss: 2.0380, Validation Loss: 2.0052
# Saved model with validation loss: 2.0052
# Epoch [16/70], Training Loss: 2.0108, Validation Loss: 1.9903
# Saved model with validation loss: 1.9903
# Epoch [17/70], Training Loss: 1.9894, Validation Loss: 1.9703
# Saved model with validation loss: 1.9703
# Epoch [18/70], Training Loss: 1.9636, Validation Loss: 1.9595
# Saved model with validation loss: 1.9595
# Epoch [19/70], Training Loss: 1.9449, Validation Loss: 1.9372
# Saved model with validation loss: 1.9372
# Epoch [20/70], Training Loss: 1.9208, Validation Loss: 1.9271
# Saved model with validation loss: 1.9271
# Epoch [21/70], Training Loss: 1.9046, Validation Loss: 1.9190
# Saved model with validation loss: 1.9190
# Epoch [22/70], Training Loss: 1.8837, Validation Loss: 1.8999
# Saved model with validation loss: 1.8999
# Epoch [23/70], Training Loss: 1.8659, Validation Loss: 1.8940
# Saved model with validation loss: 1.8940
# Epoch [24/70], Training Loss: 1.8477, Validation Loss: 1.8795
# Saved model with validation loss: 1.8795
# Epoch [25/70], Training Loss: 1.8280, Validation Loss: 1.8665
# Saved model with validation loss: 1.8665
# Epoch [26/70], Training Loss: 1.8126, Validation Loss: 1.8557
# Saved model with validation loss: 1.8557
# Epoch [27/70], Training Loss: 1.7994, Validation Loss: 1.8573
# Epoch [28/70], Training Loss: 1.7804, Validation Loss: 1.8506
# Saved model with validation loss: 1.8506
# Epoch [29/70], Training Loss: 1.7654, Validation Loss: 1.8341
# Saved model with validation loss: 1.8341
# Epoch [30/70], Training Loss: 1.7493, Validation Loss: 1.8313
# Saved model with validation loss: 1.8313
# Epoch [31/70], Training Loss: 1.7356, Validation Loss: 1.8211
# Saved model with validation loss: 1.8211
# Epoch [32/70], Training Loss: 1.7211, Validation Loss: 1.8133
# Saved model with validation loss: 1.8133
# Epoch [33/70], Training Loss: 1.7078, Validation Loss: 1.8068
# Saved model with validation loss: 1.8068
# Epoch [34/70], Training Loss: 1.6942, Validation Loss: 1.7973
# Saved model with validation loss: 1.7973
# Epoch [35/70], Training Loss: 1.6787, Validation Loss: 1.7981
# Epoch [36/70], Training Loss: 1.6689, Validation Loss: 1.7937
# Saved model with validation loss: 1.7937
# Epoch [37/70], Training Loss: 1.6550, Validation Loss: 1.7852
# Saved model with validation loss: 1.7852
# Epoch [38/70], Training Loss: 1.6446, Validation Loss: 1.7780
# Saved model with validation loss: 1.7780
# Epoch [39/70], Training Loss: 1.6291, Validation Loss: 1.7748
# Saved model with validation loss: 1.7748
# Epoch [40/70], Training Loss: 1.6174, Validation Loss: 1.7666
# Saved model with validation loss: 1.7666
# Epoch [41/70], Training Loss: 1.6013, Validation Loss: 1.7666
# Saved model with validation loss: 1.7666
# Epoch [42/70], Training Loss: 1.5933, Validation Loss: 1.7696
# Epoch [43/70], Training Loss: 1.5873, Validation Loss: 1.7592
# Saved model with validation loss: 1.7592
# Epoch [44/70], Training Loss: 1.5704, Validation Loss: 1.7519
# Saved model with validation loss: 1.7519
# Epoch [45/70], Training Loss: 1.5601, Validation Loss: 1.7526
# Epoch [46/70], Training Loss: 1.5473, Validation Loss: 1.7483
# Saved model with validation loss: 1.7483
# Epoch [47/70], Training Loss: 1.5355, Validation Loss: 1.7477
# Saved model with validation loss: 1.7477
# Epoch [48/70], Training Loss: 1.5249, Validation Loss: 1.7465
# Saved model with validation loss: 1.7465
# Epoch [49/70], Training Loss: 1.5157, Validation Loss: 1.7497
# Epoch [50/70], Training Loss: 1.5054, Validation Loss: 1.7383
# Saved model with validation loss: 1.7383
# Epoch [51/70], Training Loss: 1.4904, Validation Loss: 1.7330
# Saved model with validation loss: 1.7330
# Epoch [52/70], Training Loss: 1.4851, Validation Loss: 1.7347
# Epoch [53/70], Training Loss: 1.4727, Validation Loss: 1.7298
# Saved model with validation loss: 1.7298
# Epoch [54/70], Training Loss: 1.4618, Validation Loss: 1.7249
# Saved model with validation loss: 1.7249
# Epoch [55/70], Training Loss: 1.4568, Validation Loss: 1.7223
# Saved model with validation loss: 1.7223
# Epoch [56/70], Training Loss: 1.4398, Validation Loss: 1.7251
# Epoch [57/70], Training Loss: 1.4301, Validation Loss: 1.7252
# Epoch [58/70], Training Loss: 1.4226, Validation Loss: 1.7240
# Epoch [59/70], Training Loss: 1.4136, Validation Loss: 1.7142
# Saved model with validation loss: 1.7142
# Epoch [60/70], Training Loss: 1.4042, Validation Loss: 1.7205
# Epoch [61/70], Training Loss: 1.3968, Validation Loss: 1.7230
# Epoch [62/70], Training Loss: 1.3836, Validation Loss: 1.7196
# Epoch [63/70], Training Loss: 1.3776, Validation Loss: 1.7079
# Saved model with validation loss: 1.7079
# Epoch [64/70], Training Loss: 1.3675, Validation Loss: 1.7170
# Epoch [65/70], Training Loss: 1.3604, Validation Loss: 1.7142
# Epoch [66/70], Training Loss: 1.3481, Validation Loss: 1.7161
# Epoch [67/70], Training Loss: 1.3401, Validation Loss: 1.7170
# Epoch [68/70], Training Loss: 1.3334, Validation Loss: 1.7090
# Epoch [69/70], Training Loss: 1.3225, Validation Loss: 1.7098
# Epoch [70/70], Training Loss: 1.3122, Validation Loss: 1.7053
# Saved model with validation loss: 1.7053

# %%
import torch
from sklearn.metrics import classification_report, accuracy_score

def predict(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    predictions = []
    actuals = []

    with torch.no_grad():
        for data, targets in data_loader:
            outputs = model(data)
            _, predicted = torch.max(outputs, 1)

            predictions.extend(predicted.cpu().numpy())
            actuals.extend(targets.cpu().numpy())

    return predictions, actuals

# %%
predictions, actuals = predict(model, val_loader)

# Print the classification report
print(classification_report(actuals, predictions, target_names=[id2char[s] for s in set(actuals + predictions)]))

# Calculate and print the accuracy
accuracy = accuracy_score(actuals, predictions)
print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         1
#            C       0.33      0.75      0.46         4
#            D       0.00      0.00      0.00         0
#            E       0.29      0.14      0.19        14
#            F       0.00      0.00      0.00         1
#            G       0.64      0.35      0.45        26
#            H       0.50      1.00      0.67         1
#            I       0.25      0.17      0.20         6
#            J       0.22      0.25      0.24         8
#            K       0.50      0.64      0.56        11
#            L       0.00      0.00      0.00         1
#            M       0.92      0.61      0.73        18
#            N       0.00      0.00      0.00         2
#            P       0.68      0.63      0.65        27
#            Q       0.00      0.00      0.00         1
#            R       0.42      0.74      0.53        31
#            S       0.40      0.67      0.50        33
#            T       0.80      1.00      0.89         4
#            U       0.00      0.00      0.00         1
#            X       0.00      0.00      0.00         2
#            Y       0.00      0.00      0.00         2
#            Z       1.00      0.11      0.20         9
#            1       0.62      0.44      0.52        18
#            2       0.52      0.41      0.46        29
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.48       255
#    macro avg       0.29      0.28      0.26       255
# weighted avg       0.51      0.48      0.46       255
#
# Validation Accuracy: 0.4824
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
predictions, actuals = predict(model, test_loader)

# Print the classification report
print(classification_report(actuals, predictions, target_names=[id2char[s] for s in set(actuals + predictions)]))

# Calculate and print the accuracy
accuracy = accuracy_score(actuals, predictions)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         2
#            E       0.43      1.00      0.60         3
#            F       0.00      0.00      0.00         0
#            G       0.83      0.93      0.88        27
#            H       0.00      0.00      0.00         0
#            I       0.50      1.00      0.67         1
#            J       0.88      0.78      0.82         9
#            K       1.00      1.00      1.00        12
#            M       0.93      0.93      0.93        28
#            P       0.95      0.80      0.87       111
#            Q       0.00      0.00      0.00         0
#            R       0.85      0.90      0.87        92
#            S       0.54      0.92      0.68        24
#            T       1.00      1.00      1.00        14
#            W       0.00      0.00      0.00         0
#            1       1.00      0.65      0.79        17
#            2       0.88      0.54      0.67        39
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.83       379
#    macro avg       0.60      0.64      0.60       379
# weighted avg       0.88      0.83      0.84       379
#
# Test Accuracy: 0.8338
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/giyaseddin/miniconda3/envs/chatbot-special-language-modelling-assignment/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def create_and_train_model(input_size, hidden_size, output_size, num_hidden_layers, embedding_dim, train_loader, val_loader, learning_rate, num_epochs, model_save_path):
    # Create the model instance
    model = SimpleLSTM(input_size, hidden_size, output_size, num_hidden_layers, embedding_dim)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize the best validation loss to infinity at the start
    best_val_loss = float('inf')

    # Training function
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        for batch_idx, (data, targets) in enumerate(train_loader):
            # Forward pass
            scores = model(data)
            loss = criterion(scores, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data, targets in val_loader:
                scores = model(data)
                loss = criterion(scores, targets)
                val_loss += loss.item()

        val_loss /= len(val_loader)

        # Print training and validation loss
        print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

        # Check if this is the best model so far and save it if it is
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), model_save_path)
            print(f"Saved model with validation loss: {best_val_loss:.4f}")

    # Return the trained model and its best validation loss
    return model, best_val_loss

# %%
# Best model tracking
best_model = None
best_accuracy = 0.0
best_model_hyperparams = {}
lowest_val_loss = float('inf')

# Hyperparameters to explore
num_hidden_layers_list = [1, 2, 3]
hidden_sizes = [128, 256]
learning_rates = [0.0003, 0.0002, 0.0001]
num_epochs = 50
embedding_dims = [20, 50, 100]

# Iterate over different combinations of hyperparameters
for num_hidden_layers in num_hidden_layers_list:
    for embedding_dim in embedding_dims:
        for hidden_size in hidden_sizes:
            for lr in learning_rates:
                print(f"Training with hidden_size: {hidden_size}, learning_rate: {lr}")
        
                # Create and train the model with given hyperparameters
                model, best_val_loss = create_and_train_model(input_size, hidden_size, output_size, num_hidden_layers, embedding_dim, train_loader, test_loader, lr, num_epochs, model_save_path)
        
                print(f"Model with hidden_size {hidden_size} and learning_rate {lr} achieved validation loss: {best_val_loss}. Embedding dim: {embedding_dim}. num_hidden_layers: {num_hidden_layers}")
        
                predictions, actuals = predict(model, val_loader)
                # Calculate and print the accuracy
                accuracy = accuracy_score(actuals, predictions)
                print(f"===== Accuracy {accuracy:.4f}.")
        
                # Check if this model is the best so far
                # if best_val_loss < lowest_val_loss:
                if accuracy > best_accuracy:
                    lowest_val_loss = best_val_loss
                    best_model = model
                    best_model_hyperparams = {'hidden_size': hidden_size, 'learning_rate': lr, 'embedding_dim': embedding_dim, 'num_hidden_layers': num_hidden_layers}
                    best_accuracy = accuracy

# best_model now holds the best performing model
print(f"Best model hyperparameters: {best_model_hyperparams}")
print(f"Lowest validation loss: {lowest_val_loss}")
# Out:
# Training with hidden_size: 128, learning_rate: 0.0003
# Epoch [1/50], Training Loss: 3.3991, Validation Loss: 3.2045
# Saved model with validation loss: 3.2045
# Epoch [2/50], Training Loss: 2.9280, Validation Loss: 2.3828
# Saved model with validation loss: 2.3828
# Epoch [3/50], Training Loss: 2.6228, Validation Loss: 2.2065
# Saved model with validation loss: 2.2065
# Epoch [4/50], Training Loss: 2.5253, Validation Loss: 2.0602
# Saved model with validation loss: 2.0602
# Epoch [5/50], Training Loss: 2.4511, Validation Loss: 1.8652
# Saved model with validation loss: 1.8652
# Epoch [6/50], Training Loss: 2.3881, Validation Loss: 1.7802
# Saved model with validation loss: 1.7802
# Epoch [7/50], Training Loss: 2.3358, Validation Loss: 1.6480
# Saved model with validation loss: 1.6480
# Epoch [8/50], Training Loss: 2.2847, Validation Loss: 1.5378
# Saved model with validation loss: 1.5378
# Epoch [9/50], Training Loss: 2.2421, Validation Loss: 1.4673
# Saved model with validation loss: 1.4673
# Epoch [10/50], Training Loss: 2.2069, Validation Loss: 1.4036
# Saved model with validation loss: 1.4036
# Epoch [11/50], Training Loss: 2.1664, Validation Loss: 1.4144
# Epoch [12/50], Training Loss: 2.1390, Validation Loss: 1.3695
# Saved model with validation loss: 1.3695
# Epoch [13/50], Training Loss: 2.1059, Validation Loss: 1.2995
# Saved model with validation loss: 1.2995
# Epoch [14/50], Training Loss: 2.0779, Validation Loss: 1.2553
# Saved model with validation loss: 1.2553
# Epoch [15/50], Training Loss: 2.0526, Validation Loss: 1.2603
# Epoch [16/50], Training Loss: 2.0247, Validation Loss: 1.2207
# Saved model with validation loss: 1.2207
# Epoch [17/50], Training Loss: 2.0023, Validation Loss: 1.1874
# Saved model with validation loss: 1.1874
# Epoch [18/50], Training Loss: 1.9860, Validation Loss: 1.1751
# Saved model with validation loss: 1.1751
# Epoch [19/50], Training Loss: 1.9625, Validation Loss: 1.1295
# Saved model with validation loss: 1.1295
# Epoch [20/50], Training Loss: 1.9395, Validation Loss: 1.1455
# Epoch [21/50], Training Loss: 1.9205, Validation Loss: 1.0967
# Saved model with validation loss: 1.0967
# Epoch [22/50], Training Loss: 1.8991, Validation Loss: 1.1185
# Epoch [23/50], Training Loss: 1.8814, Validation Loss: 1.0439
# Saved model with validation loss: 1.0439
# Epoch [24/50], Training Loss: 1.8623, Validation Loss: 1.0089
# Saved model with validation loss: 1.0089
# Epoch [25/50], Training Loss: 1.8542, Validation Loss: 1.0041
# Saved model with validation loss: 1.0041
# Epoch [26/50], Training Loss: 1.8305, Validation Loss: 1.0155
# Epoch [27/50], Training Loss: 1.8157, Validation Loss: 1.0769
# Epoch [28/50], Training Loss: 1.7992, Validation Loss: 1.0146
# Epoch [29/50], Training Loss: 1.7839, Validation Loss: 1.0105
# Epoch [30/50], Training Loss: 1.7679, Validation Loss: 1.0414
# Epoch [31/50], Training Loss: 1.7566, Validation Loss: 0.9806
# Saved model with validation loss: 0.9806
# Epoch [32/50], Training Loss: 1.7330, Validation Loss: 0.9677
# Saved model with validation loss: 0.9677
# Epoch [33/50], Training Loss: 1.7193, Validation Loss: 0.9183
# Saved model with validation loss: 0.9183
# Epoch [34/50], Training Loss: 1.7083, Validation Loss: 0.9542
# Epoch [35/50], Training Loss: 1.6937, Validation Loss: 0.9020
# Saved model with validation loss: 0.9020
# Epoch [36/50], Training Loss: 1.6787, Validation Loss: 0.9594
# Epoch [37/50], Training Loss: 1.6637, Validation Loss: 0.9426
# Epoch [38/50], Training Loss: 1.6493, Validation Loss: 0.9346
# Epoch [39/50], Training Loss: 1.6378, Validation Loss: 0.9307
# Epoch [40/50], Training Loss: 1.6201, Validation Loss: 0.9035
# Epoch [41/50], Training Loss: 1.6083, Validation Loss: 0.9369
# Epoch [42/50], Training Loss: 1.5952, Validation Loss: 0.9115
# Epoch [43/50], Training Loss: 1.5860, Validation Loss: 0.9350
# Epoch [44/50], Training Loss: 1.5660, Validation Loss: 0.9466
# Epoch [45/50], Training Loss: 1.5553, Validation Loss: 0.9268
# Epoch [46/50], Training Loss: 1.5438, Validation Loss: 0.9146
# Epoch [47/50], Training Loss: 1.5284, Validation Loss: 0.9486
# Epoch [48/50], Training Loss: 1.5132, Validation Loss: 0.9548
# Epoch [49/50], Training Loss: 1.5001, Validation Loss: 0.9150
# Epoch [50/50], Training Loss: 1.4897, Validation Loss: 0.9020
# Saved model with validation loss: 0.9020
# Model with hidden_size 128 and learning_rate 0.0003 achieved validation loss: 0.9019810160001119. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4784.
# Training with hidden_size: 128, learning_rate: 0.0002
# Epoch [1/50], Training Loss: 3.4453, Validation Loss: 3.3449
# Saved model with validation loss: 3.3449
# Epoch [2/50], Training Loss: 3.1354, Validation Loss: 2.6189
# Saved model with validation loss: 2.6189
# Epoch [3/50], Training Loss: 2.6967, Validation Loss: 2.3218
# Saved model with validation loss: 2.3218
# Epoch [4/50], Training Loss: 2.6182, Validation Loss: 2.1987
# Saved model with validation loss: 2.1987
# Epoch [5/50], Training Loss: 2.5554, Validation Loss: 2.0842
# Saved model with validation loss: 2.0842
# Epoch [6/50], Training Loss: 2.4956, Validation Loss: 1.9905
# Saved model with validation loss: 1.9905
# Epoch [7/50], Training Loss: 2.4477, Validation Loss: 1.8554
# Saved model with validation loss: 1.8554
# Epoch [8/50], Training Loss: 2.4069, Validation Loss: 1.7851
# Saved model with validation loss: 1.7851
# Epoch [9/50], Training Loss: 2.3692, Validation Loss: 1.7290
# Saved model with validation loss: 1.7290
# Epoch [10/50], Training Loss: 2.3380, Validation Loss: 1.6349
# Saved model with validation loss: 1.6349
# Epoch [11/50], Training Loss: 2.3079, Validation Loss: 1.5851
# Saved model with validation loss: 1.5851
# Epoch [12/50], Training Loss: 2.2758, Validation Loss: 1.5547
# Saved model with validation loss: 1.5547
# Epoch [13/50], Training Loss: 2.2470, Validation Loss: 1.4921
# Saved model with validation loss: 1.4921
# Epoch [14/50], Training Loss: 2.2169, Validation Loss: 1.4587
# Saved model with validation loss: 1.4587
# Epoch [15/50], Training Loss: 2.1914, Validation Loss: 1.4177
# Saved model with validation loss: 1.4177
# Epoch [16/50], Training Loss: 2.1704, Validation Loss: 1.3534
# Saved model with validation loss: 1.3534
# Epoch [17/50], Training Loss: 2.1474, Validation Loss: 1.3508
# Saved model with validation loss: 1.3508
# Epoch [18/50], Training Loss: 2.1209, Validation Loss: 1.3179
# Saved model with validation loss: 1.3179
# Epoch [19/50], Training Loss: 2.0994, Validation Loss: 1.2953
# Saved model with validation loss: 1.2953
# Epoch [20/50], Training Loss: 2.0812, Validation Loss: 1.2352
# Saved model with validation loss: 1.2352
# Epoch [21/50], Training Loss: 2.0599, Validation Loss: 1.2381
# Epoch [22/50], Training Loss: 2.0449, Validation Loss: 1.2320
# Saved model with validation loss: 1.2320
# Epoch [23/50], Training Loss: 2.0265, Validation Loss: 1.2169
# Saved model with validation loss: 1.2169
# Epoch [24/50], Training Loss: 2.0092, Validation Loss: 1.1777
# Saved model with validation loss: 1.1777
# Epoch [25/50], Training Loss: 1.9956, Validation Loss: 1.1551
# Saved model with validation loss: 1.1551
# Epoch [26/50], Training Loss: 1.9784, Validation Loss: 1.1524
# Saved model with validation loss: 1.1524
# Epoch [27/50], Training Loss: 1.9645, Validation Loss: 1.1491
# Saved model with validation loss: 1.1491
# Epoch [28/50], Training Loss: 1.9515, Validation Loss: 1.1193
# Saved model with validation loss: 1.1193
# Epoch [29/50], Training Loss: 1.9374, Validation Loss: 1.0577
# Saved model with validation loss: 1.0577
# Epoch [30/50], Training Loss: 1.9270, Validation Loss: 1.0898
# Epoch [31/50], Training Loss: 1.9114, Validation Loss: 1.0843
# Epoch [32/50], Training Loss: 1.8944, Validation Loss: 1.0814
# Epoch [33/50], Training Loss: 1.8852, Validation Loss: 1.0723
# Epoch [34/50], Training Loss: 1.8769, Validation Loss: 1.0434
# Saved model with validation loss: 1.0434
# Epoch [35/50], Training Loss: 1.8621, Validation Loss: 1.0731
# Epoch [36/50], Training Loss: 1.8519, Validation Loss: 0.9920
# Saved model with validation loss: 0.9920
# Epoch [37/50], Training Loss: 1.8392, Validation Loss: 1.0536
# Epoch [38/50], Training Loss: 1.8280, Validation Loss: 1.0155
# Epoch [39/50], Training Loss: 1.8182, Validation Loss: 1.0511
# Epoch [40/50], Training Loss: 1.8088, Validation Loss: 1.0305
# Epoch [41/50], Training Loss: 1.8019, Validation Loss: 1.0204
# Epoch [42/50], Training Loss: 1.7869, Validation Loss: 0.9720
# Saved model with validation loss: 0.9720
# Epoch [43/50], Training Loss: 1.7789, Validation Loss: 0.9963
# Epoch [44/50], Training Loss: 1.7696, Validation Loss: 0.9765
# Epoch [45/50], Training Loss: 1.7570, Validation Loss: 1.0038
# Epoch [46/50], Training Loss: 1.7458, Validation Loss: 0.9709
# Saved model with validation loss: 0.9709
# Epoch [47/50], Training Loss: 1.7401, Validation Loss: 0.9718
# Epoch [48/50], Training Loss: 1.7307, Validation Loss: 0.9423
# Saved model with validation loss: 0.9423
# Epoch [49/50], Training Loss: 1.7232, Validation Loss: 0.9246
# Saved model with validation loss: 0.9246
# Epoch [50/50], Training Loss: 1.7117, Validation Loss: 0.9724
# Model with hidden_size 128 and learning_rate 0.0002 achieved validation loss: 0.9245876371860504. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4392.
# Training with hidden_size: 128, learning_rate: 0.0001
# Epoch [1/50], Training Loss: 3.4900, Validation Loss: 3.4496
# Saved model with validation loss: 3.4496
# Epoch [2/50], Training Loss: 3.4217, Validation Loss: 3.3398
# Saved model with validation loss: 3.3398
# Epoch [3/50], Training Loss: 3.2824, Validation Loss: 3.0504
# Saved model with validation loss: 3.0504
# Epoch [4/50], Training Loss: 2.9283, Validation Loss: 2.5227
# Saved model with validation loss: 2.5227
# Epoch [5/50], Training Loss: 2.7157, Validation Loss: 2.3743
# Saved model with validation loss: 2.3743
# Epoch [6/50], Training Loss: 2.6593, Validation Loss: 2.3028
# Saved model with validation loss: 2.3028
# Epoch [7/50], Training Loss: 2.6240, Validation Loss: 2.2454
# Saved model with validation loss: 2.2454
# Epoch [8/50], Training Loss: 2.5940, Validation Loss: 2.1813
# Saved model with validation loss: 2.1813
# Epoch [9/50], Training Loss: 2.5623, Validation Loss: 2.1104
# Saved model with validation loss: 2.1104
# Epoch [10/50], Training Loss: 2.5276, Validation Loss: 2.0464
# Saved model with validation loss: 2.0464
# Epoch [11/50], Training Loss: 2.4976, Validation Loss: 1.9786
# Saved model with validation loss: 1.9786
# Epoch [12/50], Training Loss: 2.4710, Validation Loss: 1.9300
# Saved model with validation loss: 1.9300
# Epoch [13/50], Training Loss: 2.4477, Validation Loss: 1.8518
# Saved model with validation loss: 1.8518
# Epoch [14/50], Training Loss: 2.4225, Validation Loss: 1.8242
# Saved model with validation loss: 1.8242
# Epoch [15/50], Training Loss: 2.4007, Validation Loss: 1.7617
# Saved model with validation loss: 1.7617
# Epoch [16/50], Training Loss: 2.3818, Validation Loss: 1.7235
# Saved model with validation loss: 1.7235
# Epoch [17/50], Training Loss: 2.3678, Validation Loss: 1.6886
# Saved model with validation loss: 1.6886
# Epoch [18/50], Training Loss: 2.3489, Validation Loss: 1.6622
# Saved model with validation loss: 1.6622
# Epoch [19/50], Training Loss: 2.3360, Validation Loss: 1.6412
# Saved model with validation loss: 1.6412
# Epoch [20/50], Training Loss: 2.3192, Validation Loss: 1.5808
# Saved model with validation loss: 1.5808
# Epoch [21/50], Training Loss: 2.3052, Validation Loss: 1.5781
# Saved model with validation loss: 1.5781
# Epoch [22/50], Training Loss: 2.2894, Validation Loss: 1.5471
# Saved model with validation loss: 1.5471
# Epoch [23/50], Training Loss: 2.2748, Validation Loss: 1.5183
# Saved model with validation loss: 1.5183
# Epoch [24/50], Training Loss: 2.2632, Validation Loss: 1.5159
# Saved model with validation loss: 1.5159
# Epoch [25/50], Training Loss: 2.2495, Validation Loss: 1.4828
# Saved model with validation loss: 1.4828
# Epoch [26/50], Training Loss: 2.2354, Validation Loss: 1.4726
# Saved model with validation loss: 1.4726
# Epoch [27/50], Training Loss: 2.2242, Validation Loss: 1.4409
# Saved model with validation loss: 1.4409
# Epoch [28/50], Training Loss: 2.2097, Validation Loss: 1.4054
# Saved model with validation loss: 1.4054
# Epoch [29/50], Training Loss: 2.1983, Validation Loss: 1.3993
# Saved model with validation loss: 1.3993
# Epoch [30/50], Training Loss: 2.1883, Validation Loss: 1.3906
# Saved model with validation loss: 1.3906
# Epoch [31/50], Training Loss: 2.1754, Validation Loss: 1.3522
# Saved model with validation loss: 1.3522
# Epoch [32/50], Training Loss: 2.1645, Validation Loss: 1.3522
# Epoch [33/50], Training Loss: 2.1538, Validation Loss: 1.3272
# Saved model with validation loss: 1.3272
# Epoch [34/50], Training Loss: 2.1418, Validation Loss: 1.3133
# Saved model with validation loss: 1.3133
# Epoch [35/50], Training Loss: 2.1314, Validation Loss: 1.3123
# Saved model with validation loss: 1.3123
# Epoch [36/50], Training Loss: 2.1202, Validation Loss: 1.3009
# Saved model with validation loss: 1.3009
# Epoch [37/50], Training Loss: 2.1114, Validation Loss: 1.2807
# Saved model with validation loss: 1.2807
# Epoch [38/50], Training Loss: 2.1044, Validation Loss: 1.2563
# Saved model with validation loss: 1.2563
# Epoch [39/50], Training Loss: 2.0947, Validation Loss: 1.2482
# Saved model with validation loss: 1.2482
# Epoch [40/50], Training Loss: 2.0863, Validation Loss: 1.2301
# Saved model with validation loss: 1.2301
# Epoch [41/50], Training Loss: 2.0737, Validation Loss: 1.2062
# Saved model with validation loss: 1.2062
# Epoch [42/50], Training Loss: 2.0680, Validation Loss: 1.2087
# Epoch [43/50], Training Loss: 2.0603, Validation Loss: 1.2054
# Saved model with validation loss: 1.2054
# Epoch [44/50], Training Loss: 2.0495, Validation Loss: 1.1954
# Saved model with validation loss: 1.1954
# Epoch [45/50], Training Loss: 2.0433, Validation Loss: 1.1801
# Saved model with validation loss: 1.1801
# Epoch [46/50], Training Loss: 2.0352, Validation Loss: 1.1742
# Saved model with validation loss: 1.1742
# Epoch [47/50], Training Loss: 2.0264, Validation Loss: 1.1394
# Saved model with validation loss: 1.1394
# Epoch [48/50], Training Loss: 2.0185, Validation Loss: 1.1506
# Epoch [49/50], Training Loss: 2.0111, Validation Loss: 1.1328
# Saved model with validation loss: 1.1328
# Epoch [50/50], Training Loss: 2.0053, Validation Loss: 1.1249
# Saved model with validation loss: 1.1249
# Model with hidden_size 128 and learning_rate 0.0001 achieved validation loss: 1.1248523990313213. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4431.
# Training with hidden_size: 256, learning_rate: 0.0003
# Epoch [1/50], Training Loss: 3.2584, Validation Loss: 2.4223
# Saved model with validation loss: 2.4223
# Epoch [2/50], Training Loss: 2.6807, Validation Loss: 2.2123
# Saved model with validation loss: 2.2123
# Epoch [3/50], Training Loss: 2.5299, Validation Loss: 1.9153
# Saved model with validation loss: 1.9153
# Epoch [4/50], Training Loss: 2.4094, Validation Loss: 1.6585
# Saved model with validation loss: 1.6585
# Epoch [5/50], Training Loss: 2.3245, Validation Loss: 1.4927
# Saved model with validation loss: 1.4927
# Epoch [6/50], Training Loss: 2.2493, Validation Loss: 1.4323
# Saved model with validation loss: 1.4323
# Epoch [7/50], Training Loss: 2.2017, Validation Loss: 1.3451
# Saved model with validation loss: 1.3451
# Epoch [8/50], Training Loss: 2.1587, Validation Loss: 1.3077
# Saved model with validation loss: 1.3077
# Epoch [9/50], Training Loss: 2.1063, Validation Loss: 1.3062
# Saved model with validation loss: 1.3062
# Epoch [10/50], Training Loss: 2.0750, Validation Loss: 1.1674
# Saved model with validation loss: 1.1674
# Epoch [11/50], Training Loss: 2.0377, Validation Loss: 1.1604
# Saved model with validation loss: 1.1604
# Epoch [12/50], Training Loss: 1.9936, Validation Loss: 1.0266
# Saved model with validation loss: 1.0266
# Epoch [13/50], Training Loss: 1.9706, Validation Loss: 1.0669
# Epoch [14/50], Training Loss: 1.9409, Validation Loss: 1.0042
# Saved model with validation loss: 1.0042
# Epoch [15/50], Training Loss: 1.9105, Validation Loss: 1.0668
# Epoch [16/50], Training Loss: 1.8846, Validation Loss: 0.9777
# Saved model with validation loss: 0.9777
# Epoch [17/50], Training Loss: 1.8605, Validation Loss: 0.9790
# Epoch [18/50], Training Loss: 1.8436, Validation Loss: 0.9194
# Saved model with validation loss: 0.9194
# Epoch [19/50], Training Loss: 1.8249, Validation Loss: 0.9328
# Epoch [20/50], Training Loss: 1.7974, Validation Loss: 0.9181
# Saved model with validation loss: 0.9181
# Epoch [21/50], Training Loss: 1.7641, Validation Loss: 0.8852
# Saved model with validation loss: 0.8852
# Epoch [22/50], Training Loss: 1.7459, Validation Loss: 0.8727
# Saved model with validation loss: 0.8727
# Epoch [23/50], Training Loss: 1.7235, Validation Loss: 0.8595
# Saved model with validation loss: 0.8595
# Epoch [24/50], Training Loss: 1.7026, Validation Loss: 0.8649
# Epoch [25/50], Training Loss: 1.6792, Validation Loss: 0.8594
# Saved model with validation loss: 0.8594
# Epoch [26/50], Training Loss: 1.6537, Validation Loss: 0.9090
# Epoch [27/50], Training Loss: 1.6419, Validation Loss: 0.8733
# Epoch [28/50], Training Loss: 1.6212, Validation Loss: 0.8463
# Saved model with validation loss: 0.8463
# Epoch [29/50], Training Loss: 1.5891, Validation Loss: 0.8747
# Epoch [30/50], Training Loss: 1.5716, Validation Loss: 0.8450
# Saved model with validation loss: 0.8450
# Epoch [31/50], Training Loss: 1.5460, Validation Loss: 0.8316
# Saved model with validation loss: 0.8316
# Epoch [32/50], Training Loss: 1.5277, Validation Loss: 0.8451
# Epoch [33/50], Training Loss: 1.5070, Validation Loss: 0.8348
# Epoch [34/50], Training Loss: 1.4892, Validation Loss: 0.8581
# Epoch [35/50], Training Loss: 1.4665, Validation Loss: 0.8756
# Epoch [36/50], Training Loss: 1.4425, Validation Loss: 0.8258
# Saved model with validation loss: 0.8258
# Epoch [37/50], Training Loss: 1.4353, Validation Loss: 0.8131
# Saved model with validation loss: 0.8131
# Epoch [38/50], Training Loss: 1.4066, Validation Loss: 0.7935
# Saved model with validation loss: 0.7935
# Epoch [39/50], Training Loss: 1.3816, Validation Loss: 0.8693
# Epoch [40/50], Training Loss: 1.3628, Validation Loss: 0.8209
# Epoch [41/50], Training Loss: 1.3445, Validation Loss: 0.8021
# Epoch [42/50], Training Loss: 1.3226, Validation Loss: 0.7836
# Saved model with validation loss: 0.7836
# Epoch [43/50], Training Loss: 1.3108, Validation Loss: 0.8393
# Epoch [44/50], Training Loss: 1.2809, Validation Loss: 0.8103
# Epoch [45/50], Training Loss: 1.2659, Validation Loss: 0.9132
# Epoch [46/50], Training Loss: 1.2470, Validation Loss: 0.8257
# Epoch [47/50], Training Loss: 1.2263, Validation Loss: 0.8304
# Epoch [48/50], Training Loss: 1.2079, Validation Loss: 0.7990
# Epoch [49/50], Training Loss: 1.1843, Validation Loss: 0.7974
# Epoch [50/50], Training Loss: 1.1693, Validation Loss: 0.8299
# Model with hidden_size 256 and learning_rate 0.0003 achieved validation loss: 0.7835733195145925. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4431.
# Training with hidden_size: 256, learning_rate: 0.0002
# Epoch [1/50], Training Loss: 3.3917, Validation Loss: 3.1647
# Saved model with validation loss: 3.1647
# Epoch [2/50], Training Loss: 2.8361, Validation Loss: 2.2589
# Saved model with validation loss: 2.2589
# Epoch [3/50], Training Loss: 2.5761, Validation Loss: 2.0895
# Saved model with validation loss: 2.0895
# Epoch [4/50], Training Loss: 2.4812, Validation Loss: 1.9303
# Saved model with validation loss: 1.9303
# Epoch [5/50], Training Loss: 2.4127, Validation Loss: 1.7424
# Saved model with validation loss: 1.7424
# Epoch [6/50], Training Loss: 2.3594, Validation Loss: 1.6650
# Saved model with validation loss: 1.6650
# Epoch [7/50], Training Loss: 2.3044, Validation Loss: 1.5462
# Saved model with validation loss: 1.5462
# Epoch [8/50], Training Loss: 2.2636, Validation Loss: 1.4607
# Saved model with validation loss: 1.4607
# Epoch [9/50], Training Loss: 2.2274, Validation Loss: 1.4766
# Epoch [10/50], Training Loss: 2.1853, Validation Loss: 1.3858
# Saved model with validation loss: 1.3858
# Epoch [11/50], Training Loss: 2.1492, Validation Loss: 1.3223
# Saved model with validation loss: 1.3223
# Epoch [12/50], Training Loss: 2.1203, Validation Loss: 1.3283
# Epoch [13/50], Training Loss: 2.0902, Validation Loss: 1.2616
# Saved model with validation loss: 1.2616
# Epoch [14/50], Training Loss: 2.0714, Validation Loss: 1.2512
# Saved model with validation loss: 1.2512
# Epoch [15/50], Training Loss: 2.0370, Validation Loss: 1.2604
# Epoch [16/50], Training Loss: 2.0096, Validation Loss: 1.1746
# Saved model with validation loss: 1.1746
# Epoch [17/50], Training Loss: 1.9917, Validation Loss: 1.1515
# Saved model with validation loss: 1.1515
# Epoch [18/50], Training Loss: 1.9700, Validation Loss: 1.1803
# Epoch [19/50], Training Loss: 1.9492, Validation Loss: 1.1306
# Saved model with validation loss: 1.1306
# Epoch [20/50], Training Loss: 1.9278, Validation Loss: 1.1064
# Saved model with validation loss: 1.1064
# Epoch [21/50], Training Loss: 1.9057, Validation Loss: 1.0475
# Saved model with validation loss: 1.0475
# Epoch [22/50], Training Loss: 1.8926, Validation Loss: 1.0507
# Epoch [23/50], Training Loss: 1.8738, Validation Loss: 1.0177
# Saved model with validation loss: 1.0177
# Epoch [24/50], Training Loss: 1.8566, Validation Loss: 1.0332
# Epoch [25/50], Training Loss: 1.8369, Validation Loss: 1.0593
# Epoch [26/50], Training Loss: 1.8206, Validation Loss: 1.0399
# Epoch [27/50], Training Loss: 1.8016, Validation Loss: 1.0201
# Epoch [28/50], Training Loss: 1.7884, Validation Loss: 1.0296
# Epoch [29/50], Training Loss: 1.7728, Validation Loss: 1.0107
# Saved model with validation loss: 1.0107
# Epoch [30/50], Training Loss: 1.7517, Validation Loss: 1.0301
# Epoch [31/50], Training Loss: 1.7368, Validation Loss: 0.9709
# Saved model with validation loss: 0.9709
# Epoch [32/50], Training Loss: 1.7231, Validation Loss: 1.0263
# Epoch [33/50], Training Loss: 1.7096, Validation Loss: 0.9535
# Saved model with validation loss: 0.9535
# Epoch [34/50], Training Loss: 1.6957, Validation Loss: 1.0024
# Epoch [35/50], Training Loss: 1.6731, Validation Loss: 0.9399
# Saved model with validation loss: 0.9399
# Epoch [36/50], Training Loss: 1.6560, Validation Loss: 0.9640
# Epoch [37/50], Training Loss: 1.6432, Validation Loss: 0.9500
# Epoch [38/50], Training Loss: 1.6293, Validation Loss: 0.9180
# Saved model with validation loss: 0.9180
# Epoch [39/50], Training Loss: 1.6160, Validation Loss: 0.9507
# Epoch [40/50], Training Loss: 1.6000, Validation Loss: 0.9884
# Epoch [41/50], Training Loss: 1.5814, Validation Loss: 0.9696
# Epoch [42/50], Training Loss: 1.5625, Validation Loss: 0.8801
# Saved model with validation loss: 0.8801
# Epoch [43/50], Training Loss: 1.5579, Validation Loss: 0.8970
# Epoch [44/50], Training Loss: 1.5373, Validation Loss: 0.9535
# Epoch [45/50], Training Loss: 1.5193, Validation Loss: 0.9160
# Epoch [46/50], Training Loss: 1.5053, Validation Loss: 0.9268
# Epoch [47/50], Training Loss: 1.4918, Validation Loss: 0.9250
# Epoch [48/50], Training Loss: 1.4814, Validation Loss: 0.9240
# Epoch [49/50], Training Loss: 1.4623, Validation Loss: 0.9213
# Epoch [50/50], Training Loss: 1.4463, Validation Loss: 0.8714
# Saved model with validation loss: 0.8714
# Model with hidden_size 256 and learning_rate 0.0002 achieved validation loss: 0.8714237610499064. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4353.
# Training with hidden_size: 256, learning_rate: 0.0001
# Epoch [1/50], Training Loss: 3.4563, Validation Loss: 3.3978
# Saved model with validation loss: 3.3978
# Epoch [2/50], Training Loss: 3.3139, Validation Loss: 3.0837
# Saved model with validation loss: 3.0837
# Epoch [3/50], Training Loss: 2.8540, Validation Loss: 2.3686
# Saved model with validation loss: 2.3686
# Epoch [4/50], Training Loss: 2.6512, Validation Loss: 2.2848
# Saved model with validation loss: 2.2848
# Epoch [5/50], Training Loss: 2.5872, Validation Loss: 2.1586
# Saved model with validation loss: 2.1586
# Epoch [6/50], Training Loss: 2.5282, Validation Loss: 2.0659
# Saved model with validation loss: 2.0659
# Epoch [7/50], Training Loss: 2.4769, Validation Loss: 1.9757
# Saved model with validation loss: 1.9757
# Epoch [8/50], Training Loss: 2.4396, Validation Loss: 1.8796
# Saved model with validation loss: 1.8796
# Epoch [9/50], Training Loss: 2.4065, Validation Loss: 1.7933
# Saved model with validation loss: 1.7933
# Epoch [10/50], Training Loss: 2.3753, Validation Loss: 1.7509
# Saved model with validation loss: 1.7509
# Epoch [11/50], Training Loss: 2.3515, Validation Loss: 1.6962
# Saved model with validation loss: 1.6962
# Epoch [12/50], Training Loss: 2.3286, Validation Loss: 1.6746
# Saved model with validation loss: 1.6746
# Epoch [13/50], Training Loss: 2.3079, Validation Loss: 1.6140
# Saved model with validation loss: 1.6140
# Epoch [14/50], Training Loss: 2.2825, Validation Loss: 1.5601
# Saved model with validation loss: 1.5601
# Epoch [15/50], Training Loss: 2.2655, Validation Loss: 1.5494
# Saved model with validation loss: 1.5494
# Epoch [16/50], Training Loss: 2.2445, Validation Loss: 1.5160
# Saved model with validation loss: 1.5160
# Epoch [17/50], Training Loss: 2.2259, Validation Loss: 1.4593
# Saved model with validation loss: 1.4593
# Epoch [18/50], Training Loss: 2.2070, Validation Loss: 1.4525
# Saved model with validation loss: 1.4525
# Epoch [19/50], Training Loss: 2.1906, Validation Loss: 1.3751
# Saved model with validation loss: 1.3751
# Epoch [20/50], Training Loss: 2.1783, Validation Loss: 1.3769
# Epoch [21/50], Training Loss: 2.1605, Validation Loss: 1.3567
# Saved model with validation loss: 1.3567
# Epoch [22/50], Training Loss: 2.1466, Validation Loss: 1.3265
# Saved model with validation loss: 1.3265
# Epoch [23/50], Training Loss: 2.1342, Validation Loss: 1.2987
# Saved model with validation loss: 1.2987
# Epoch [24/50], Training Loss: 2.1205, Validation Loss: 1.3084
# Epoch [25/50], Training Loss: 2.1083, Validation Loss: 1.2975
# Saved model with validation loss: 1.2975
# Epoch [26/50], Training Loss: 2.0946, Validation Loss: 1.2499
# Saved model with validation loss: 1.2499
# Epoch [27/50], Training Loss: 2.0796, Validation Loss: 1.2344
# Saved model with validation loss: 1.2344
# Epoch [28/50], Training Loss: 2.0682, Validation Loss: 1.2516
# Epoch [29/50], Training Loss: 2.0572, Validation Loss: 1.2511
# Epoch [30/50], Training Loss: 2.0449, Validation Loss: 1.1856
# Saved model with validation loss: 1.1856
# Epoch [31/50], Training Loss: 2.0355, Validation Loss: 1.1891
# Epoch [32/50], Training Loss: 2.0233, Validation Loss: 1.2021
# Epoch [33/50], Training Loss: 2.0130, Validation Loss: 1.1652
# Saved model with validation loss: 1.1652
# Epoch [34/50], Training Loss: 2.0004, Validation Loss: 1.1749
# Epoch [35/50], Training Loss: 1.9944, Validation Loss: 1.1558
# Saved model with validation loss: 1.1558
# Epoch [36/50], Training Loss: 1.9839, Validation Loss: 1.1880
# Epoch [37/50], Training Loss: 1.9723, Validation Loss: 1.1092
# Saved model with validation loss: 1.1092
# Epoch [38/50], Training Loss: 1.9597, Validation Loss: 1.0937
# Saved model with validation loss: 1.0937
# Epoch [39/50], Training Loss: 1.9505, Validation Loss: 1.1132
# Epoch [40/50], Training Loss: 1.9448, Validation Loss: 1.1096
# Epoch [41/50], Training Loss: 1.9357, Validation Loss: 1.1082
# Epoch [42/50], Training Loss: 1.9252, Validation Loss: 1.0891
# Saved model with validation loss: 1.0891
# Epoch [43/50], Training Loss: 1.9118, Validation Loss: 1.0727
# Saved model with validation loss: 1.0727
# Epoch [44/50], Training Loss: 1.9048, Validation Loss: 1.0523
# Saved model with validation loss: 1.0523
# Epoch [45/50], Training Loss: 1.8949, Validation Loss: 1.0519
# Saved model with validation loss: 1.0519
# Epoch [46/50], Training Loss: 1.8863, Validation Loss: 1.0279
# Saved model with validation loss: 1.0279
# Epoch [47/50], Training Loss: 1.8765, Validation Loss: 1.0719
# Epoch [48/50], Training Loss: 1.8679, Validation Loss: 1.0311
# Epoch [49/50], Training Loss: 1.8591, Validation Loss: 1.0315
# Epoch [50/50], Training Loss: 1.8490, Validation Loss: 1.0338
# Model with hidden_size 256 and learning_rate 0.0001 achieved validation loss: 1.0279089311758678. Embedding dim: 20. num_hidden_layers: 1
# ===== Accuracy 0.4314.
# Training with hidden_size: 128, learning_rate: 0.0003
# Epoch [1/50], Training Loss: 3.3368, Validation Loss: 3.0135
# Saved model with validation loss: 3.0135
# Epoch [2/50], Training Loss: 2.8147, Validation Loss: 2.1289
# Saved model with validation loss: 2.1289
# Epoch [3/50], Training Loss: 2.4962, Validation Loss: 1.7897
# Saved model with validation loss: 1.7897
# Epoch [4/50], Training Loss: 2.3608, Validation Loss: 1.5345
# Saved model with validation loss: 1.5345
# Epoch [5/50], Training Loss: 2.2662, Validation Loss: 1.4620
# Saved model with validation loss: 1.4620
# Epoch [6/50], Training Loss: 2.1942, Validation Loss: 1.3147
# Saved model with validation loss: 1.3147
# Epoch [7/50], Training Loss: 2.1396, Validation Loss: 1.2289
# Saved model with validation loss: 1.2289
# Epoch [8/50], Training Loss: 2.0878, Validation Loss: 1.1707
# Saved model with validation loss: 1.1707
# Epoch [9/50], Training Loss: 2.0450, Validation Loss: 1.1213
# Saved model with validation loss: 1.1213
# Epoch [10/50], Training Loss: 2.0048, Validation Loss: 1.0915
# Saved model with validation loss: 1.0915
# Epoch [11/50], Training Loss: 1.9684, Validation Loss: 1.0476
# Saved model with validation loss: 1.0476
# Epoch [12/50], Training Loss: 1.9329, Validation Loss: 1.0479
# Epoch [13/50], Training Loss: 1.9034, Validation Loss: 1.0088
# Saved model with validation loss: 1.0088
# Epoch [14/50], Training Loss: 1.8782, Validation Loss: 1.0238
# Epoch [15/50], Training Loss: 1.8468, Validation Loss: 0.9855
# Saved model with validation loss: 0.9855
# Epoch [16/50], Training Loss: 1.8211, Validation Loss: 0.9566
# Saved model with validation loss: 0.9566
# Epoch [17/50], Training Loss: 1.7962, Validation Loss: 0.9516
# Saved model with validation loss: 0.9516
# Epoch [18/50], Training Loss: 1.7706, Validation Loss: 0.9240
# Saved model with validation loss: 0.9240
# Epoch [19/50], Training Loss: 1.7542, Validation Loss: 0.8961
# Saved model with validation loss: 0.8961
# Epoch [20/50], Training Loss: 1.7265, Validation Loss: 0.8842
# Saved model with validation loss: 0.8842
# Epoch [21/50], Training Loss: 1.7071, Validation Loss: 0.9246
# Epoch [22/50], Training Loss: 1.6864, Validation Loss: 0.8936
# Epoch [23/50], Training Loss: 1.6678, Validation Loss: 0.8949
# Epoch [24/50], Training Loss: 1.6484, Validation Loss: 0.8347
# Saved model with validation loss: 0.8347
# Epoch [25/50], Training Loss: 1.6246, Validation Loss: 0.8680
# Epoch [26/50], Training Loss: 1.6151, Validation Loss: 0.8336
# Saved model with validation loss: 0.8336
# Epoch [27/50], Training Loss: 1.5925, Validation Loss: 0.8454
# Epoch [28/50], Training Loss: 1.5699, Validation Loss: 0.8467
# Epoch [29/50], Training Loss: 1.5542, Validation Loss: 0.8232
# Saved model with validation loss: 0.8232
# Epoch [30/50], Training Loss: 1.5367, Validation Loss: 0.8513
# Epoch [31/50], Training Loss: 1.5238, Validation Loss: 0.8488
# Epoch [32/50], Training Loss: 1.5080, Validation Loss: 0.7891
# Saved model with validation loss: 0.7891
# Epoch [33/50], Training Loss: 1.4897, Validation Loss: 0.8138
# Epoch [34/50], Training Loss: 1.4707, Validation Loss: 0.8435
# Epoch [35/50], Training Loss: 1.4608, Validation Loss: 0.8024
# Epoch [36/50], Training Loss: 1.4447, Validation Loss: 0.8127
# Epoch [37/50], Training Loss: 1.4279, Validation Loss: 0.8266
# Epoch [38/50], Training Loss: 1.4190, Validation Loss: 0.8024
# Epoch [39/50], Training Loss: 1.4072, Validation Loss: 0.8019
# Epoch [40/50], Training Loss: 1.3868, Validation Loss: 0.7773
# Saved model with validation loss: 0.7773
# Epoch [41/50], Training Loss: 1.3672, Validation Loss: 0.7587
# Saved model with validation loss: 0.7587
# Epoch [42/50], Training Loss: 1.3570, Validation Loss: 0.8191
# Epoch [43/50], Training Loss: 1.3411, Validation Loss: 0.7928
# Epoch [44/50], Training Loss: 1.3276, Validation Loss: 0.7925
# Epoch [45/50], Training Loss: 1.3150, Validation Loss: 0.8017
# Epoch [46/50], Training Loss: 1.2984, Validation Loss: 0.7974
# Epoch [47/50], Training Loss: 1.2907, Validation Loss: 0.7982
# Epoch [48/50], Training Loss: 1.2738, Validation Loss: 0.8151
# Epoch [49/50], Training Loss: 1.2600, Validation Loss: 0.7515
# Saved model with validation loss: 0.7515
# Epoch [50/50], Training Loss: 1.2493, Validation Loss: 0.7742
# Model with hidden_size 128 and learning_rate 0.0003 achieved validation loss: 0.7514731188615164. Embedding dim: 50. num_hidden_layers: 1
# ===== Accuracy 0.4549.
# Training with hidden_size: 128, learning_rate: 0.0002
# Epoch [1/50], Training Loss: 3.4023, Validation Loss: 3.2560
# Saved model with validation loss: 3.2560
# Epoch [2/50], Training Loss: 3.0720, Validation Loss: 2.6118
# Saved model with validation loss: 2.6118
# Epoch [3/50], Training Loss: 2.6489, Validation Loss: 2.1506
# Saved model with validation loss: 2.1506
# Epoch [4/50], Training Loss: 2.5217, Validation Loss: 1.9815
# Saved model with validation loss: 1.9815
# Epoch [5/50], Training Loss: 2.4424, Validation Loss: 1.8350
# Saved model with validation loss: 1.8350
# Epoch [6/50], Training Loss: 2.3790, Validation Loss: 1.6807
# Saved model with validation loss: 1.6807
# Epoch [7/50], Training Loss: 2.3247, Validation Loss: 1.6143
# Saved model with validation loss: 1.6143
# Epoch [8/50], Training Loss: 2.2753, Validation Loss: 1.5264
# Saved model with validation loss: 1.5264
# Epoch [9/50], Training Loss: 2.2333, Validation Loss: 1.4567
# Saved model with validation loss: 1.4567
# Epoch [10/50], Training Loss: 2.1910, Validation Loss: 1.3721
# Saved model with validation loss: 1.3721
# Epoch [11/50], Training Loss: 2.1525, Validation Loss: 1.3049
# Saved model with validation loss: 1.3049
# Epoch [12/50], Training Loss: 2.1188, Validation Loss: 1.2564
# Saved model with validation loss: 1.2564
# Epoch [13/50], Training Loss: 2.0826, Validation Loss: 1.2441
# Saved model with validation loss: 1.2441
# Epoch [14/50], Training Loss: 2.0515, Validation Loss: 1.1920
# Saved model with validation loss: 1.1920
# Epoch [15/50], Training Loss: 2.0266, Validation Loss: 1.1292
# Saved model with validation loss: 1.1292
# Epoch [16/50], Training Loss: 1.9944, Validation Loss: 1.1046
# Saved model with validation loss: 1.1046
# Epoch [17/50], Training Loss: 1.9719, Validation Loss: 1.0870
# Saved model with validation loss: 1.0870
# Epoch [18/50], Training Loss: 1.9534, Validation Loss: 1.0456
# Saved model with validation loss: 1.0456
# Epoch [19/50], Training Loss: 1.9255, Validation Loss: 1.0171
# Saved model with validation loss: 1.0171
# Epoch [20/50], Training Loss: 1.9062, Validation Loss: 1.0030
# Saved model with validation loss: 1.0030
# Epoch [21/50], Training Loss: 1.8836, Validation Loss: 0.9912
# Saved model with validation loss: 0.9912
# Epoch [22/50], Training Loss: 1.8670, Validation Loss: 0.9937
# Epoch [23/50], Training Loss: 1.8509, Validation Loss: 0.9727
# Saved model with validation loss: 0.9727
# Epoch [24/50], Training Loss: 1.8274, Validation Loss: 0.9472
# Saved model with validation loss: 0.9472
# Epoch [25/50], Training Loss: 1.8108, Validation Loss: 0.9256
# Saved model with validation loss: 0.9256
# Epoch [26/50], Training Loss: 1.7969, Validation Loss: 0.9356
# Epoch [27/50], Training Loss: 1.7776, Validation Loss: 0.9021
# Saved model with validation loss: 0.9021
# Epoch [28/50], Training Loss: 1.7636, Validation Loss: 0.9059
# Epoch [29/50], Training Loss: 1.7497, Validation Loss: 0.8919
# Saved model with validation loss: 0.8919
# Epoch [30/50], Training Loss: 1.7325, Validation Loss: 0.8630
# Saved model with validation loss: 0.8630
# Epoch [31/50], Training Loss: 1.7178, Validation Loss: 0.9089
# Epoch [32/50], Training Loss: 1.7025, Validation Loss: 0.8450
# Saved model with validation loss: 0.8450
# Epoch [33/50], Training Loss: 1.6898, Validation Loss: 0.8308
# Saved model with validation loss: 0.8308
# Epoch [34/50], Training Loss: 1.6760, Validation Loss: 0.8671
# Epoch [35/50], Training Loss: 1.6656, Validation Loss: 0.8553
# Epoch [36/50], Training Loss: 1.6467, Validation Loss: 0.8308
# Saved model with validation loss: 0.8308
# Epoch [37/50], Training Loss: 1.6365, Validation Loss: 0.8361
# Epoch [38/50], Training Loss: 1.6231, Validation Loss: 0.8445
# Epoch [39/50], Training Loss: 1.6099, Validation Loss: 0.8509
# Epoch [40/50], Training Loss: 1.5981, Validation Loss: 0.8326
# Epoch [41/50], Training Loss: 1.5887, Validation Loss: 0.8208
# Saved model with validation loss: 0.8208
# Epoch [42/50], Training Loss: 1.5744, Validation Loss: 0.8057
# Saved model with validation loss: 0.8057
# Epoch [43/50], Training Loss: 1.5599, Validation Loss: 0.8056
# Saved model with validation loss: 0.8056
# Epoch [44/50], Training Loss: 1.5504, Validation Loss: 0.8384
# Epoch [45/50], Training Loss: 1.5354, Validation Loss: 0.8175
# Epoch [46/50], Training Loss: 1.5325, Validation Loss: 0.8493
# Epoch [47/50], Training Loss: 1.5136, Validation Loss: 0.7918
# Saved model with validation loss: 0.7918
# Epoch [48/50], Training Loss: 1.5012, Validation Loss: 0.8228
# Epoch [49/50], Training Loss: 1.4936, Validation Loss: 0.7981
# Epoch [50/50], Training Loss: 1.4785, Validation Loss: 0.8020
# Model with hidden_size 128 and learning_rate 0.0002 achieved validation loss: 0.7918189565340678. Embedding dim: 50. num_hidden_layers: 1
# ===== Accuracy 0.4745.
# Training with hidden_size: 128, learning_rate: 0.0001
# Epoch [1/50], Training Loss: 3.4536, Validation Loss: 3.3504
# Saved model with validation loss: 3.3504
# Epoch [2/50], Training Loss: 3.3296, Validation Loss: 3.1593
# Saved model with validation loss: 3.1593
# Epoch [3/50], Training Loss: 3.1107, Validation Loss: 2.7788
# Saved model with validation loss: 2.7788
# Epoch [4/50], Training Loss: 2.8064, Validation Loss: 2.4425
# Saved model with validation loss: 2.4425
# Epoch [5/50], Training Loss: 2.6746, Validation Loss: 2.2813
# Saved model with validation loss: 2.2813
# Epoch [6/50], Training Loss: 2.6096, Validation Loss: 2.1784
# Saved model with validation loss: 2.1784
# Epoch [7/50], Training Loss: 2.5545, Validation Loss: 2.0768
# Saved model with validation loss: 2.0768
# Epoch [8/50], Training Loss: 2.5031, Validation Loss: 1.9943
# Saved model with validation loss: 1.9943
# Epoch [9/50], Training Loss: 2.4572, Validation Loss: 1.9027
# Saved model with validation loss: 1.9027
# Epoch [10/50], Training Loss: 2.4154, Validation Loss: 1.8315
# Saved model with validation loss: 1.8315
# Epoch [11/50], Training Loss: 2.3794, Validation Loss: 1.7555
# Saved model with validation loss: 1.7555
# Epoch [12/50], Training Loss: 2.3455, Validation Loss: 1.6943
# Saved model with validation loss: 1.6943
# Epoch [13/50], Training Loss: 2.3151, Validation Loss: 1.6332
# Saved model with validation loss: 1.6332
# Epoch [14/50], Training Loss: 2.2846, Validation Loss: 1.5879
# Saved model with validation loss: 1.5879
# Epoch [15/50], Training Loss: 2.2593, Validation Loss: 1.5368
# Saved model with validation loss: 1.5368
# Epoch [16/50], Training Loss: 2.2366, Validation Loss: 1.4940
# Saved model with validation loss: 1.4940
# Epoch [17/50], Training Loss: 2.2100, Validation Loss: 1.4535
# Saved model with validation loss: 1.4535
# Epoch [18/50], Training Loss: 2.1877, Validation Loss: 1.4132
# Saved model with validation loss: 1.4132
# Epoch [19/50], Training Loss: 2.1663, Validation Loss: 1.3799
# Saved model with validation loss: 1.3799
# Epoch [20/50], Training Loss: 2.1465, Validation Loss: 1.3404
# Saved model with validation loss: 1.3404
# Epoch [21/50], Training Loss: 2.1261, Validation Loss: 1.3221
# Saved model with validation loss: 1.3221
# Epoch [22/50], Training Loss: 2.1110, Validation Loss: 1.3100
# Saved model with validation loss: 1.3100
# Epoch [23/50], Training Loss: 2.0908, Validation Loss: 1.2622
# Saved model with validation loss: 1.2622
# Epoch [24/50], Training Loss: 2.0725, Validation Loss: 1.2465
# Saved model with validation loss: 1.2465
# Epoch [25/50], Training Loss: 2.0600, Validation Loss: 1.2185
# Saved model with validation loss: 1.2185
# Epoch [26/50], Training Loss: 2.0443, Validation Loss: 1.2006
# Saved model with validation loss: 1.2006
# Epoch [27/50], Training Loss: 2.0313, Validation Loss: 1.1876
# Saved model with validation loss: 1.1876
# Epoch [28/50], Training Loss: 2.0184, Validation Loss: 1.1840
# Saved model with validation loss: 1.1840
# Epoch [29/50], Training Loss: 2.0021, Validation Loss: 1.1339
# Saved model with validation loss: 1.1339
# Epoch [30/50], Training Loss: 1.9904, Validation Loss: 1.1372
# Epoch [31/50], Training Loss: 1.9799, Validation Loss: 1.1041
# Saved model with validation loss: 1.1041
# Epoch [32/50], Training Loss: 1.9690, Validation Loss: 1.1117
# Epoch [33/50], Training Loss: 1.9568, Validation Loss: 1.0796
# Saved model with validation loss: 1.0796
# Epoch [34/50], Training Loss: 1.9434, Validation Loss: 1.0849
# Epoch [35/50], Training Loss: 1.9349, Validation Loss: 1.0715
# Saved model with validation loss: 1.0715
# Epoch [36/50], Training Loss: 1.9238, Validation Loss: 1.0604
# Saved model with validation loss: 1.0604
# Epoch [37/50], Training Loss: 1.9117, Validation Loss: 1.0596
# Saved model with validation loss: 1.0596
# Epoch [38/50], Training Loss: 1.9015, Validation Loss: 1.0282
# Saved model with validation loss: 1.0282
# Epoch [39/50], Training Loss: 1.8931, Validation Loss: 1.0214
# Saved model with validation loss: 1.0214
# Epoch [40/50], Training Loss: 1.8870, Validation Loss: 1.0111
# Saved model with validation loss: 1.0111
# Epoch [41/50], Training Loss: 1.8722, Validation Loss: 1.0088
# Saved model with validation loss: 1.0088
# Epoch [42/50], Training Loss: 1.8674, Validation Loss: 0.9971
# Saved model with validation loss: 0.9971
# Epoch [43/50], Training Loss: 1.8545, Validation Loss: 0.9954
# Saved model with validation loss: 0.9954
# Epoch [44/50], Training Loss: 1.8488, Validation Loss: 1.0020
# Epoch [45/50], Training Loss: 1.8392, Validation Loss: 0.9722
# Saved model with validation loss: 0.9722
# Epoch [46/50], Training Loss: 1.8323, Validation Loss: 0.9670
# Saved model with validation loss: 0.9670
# Epoch [47/50], Training Loss: 1.8258, Validation Loss: 0.9765
# Epoch [48/50], Training Loss: 1.8154, Validation Loss: 0.9810
# Epoch [49/50], Training Loss: 1.8069, Validation Loss: 0.9494
# Saved model with validation loss: 0.9494
# Epoch [50/50], Training Loss: 1.7987, Validation Loss: 0.9523
# Model with hidden_size 128 and learning_rate 0.0001 achieved validation loss: 0.9494437376658121. Embedding dim: 50. num_hidden_layers: 1
# ===== Accuracy 0.4549.
# Training with hidden_size: 256, learning_rate: 0.0003
# Epoch [1/50], Training Loss: 3.1276, Validation Loss: 2.2726
# Saved model with validation loss: 2.2726
# Epoch [2/50], Training Loss: 2.5239, Validation Loss: 1.8800
# Saved model with validation loss: 1.8800
# Epoch [3/50], Training Loss: 2.3590, Validation Loss: 1.5876
# Saved model with validation loss: 1.5876
# Epoch [4/50], Training Loss: 2.2530, Validation Loss: 1.3617
# Saved model with validation loss: 1.3617
# Epoch [5/50], Training Loss: 2.1693, Validation Loss: 1.2448
# Saved model with validation loss: 1.2448
# Epoch [6/50], Training Loss: 2.1008, Validation Loss: 1.2305
# Saved model with validation loss: 1.2305
# Epoch [7/50], Training Loss: 2.0364, Validation Loss: 1.1875
# Saved model with validation loss: 1.1875
# Epoch [8/50], Training Loss: 1.9827, Validation Loss: 1.0791
# Saved model with validation loss: 1.0791
# Epoch [9/50], Training Loss: 1.9241, Validation Loss: 1.0186
# Saved model with validation loss: 1.0186
# Epoch [10/50], Training Loss: 1.8854, Validation Loss: 1.0094
# Saved model with validation loss: 1.0094
# Epoch [11/50], Training Loss: 1.8381, Validation Loss: 0.9389
# Saved model with validation loss: 0.9389
# Epoch [12/50], Training Loss: 1.8063, Validation Loss: 0.9041
# Saved model with validation loss: 0.9041
# Epoch [13/50], Training Loss: 1.7656, Validation Loss: 0.9829
# Epoch [14/50], Training Loss: 1.7360, Validation Loss: 0.8967
# Saved model with validation loss: 0.8967
# Epoch [15/50], Training Loss: 1.7032, Validation Loss: 0.8860
# Saved model with validation loss: 0.8860
# Epoch [16/50], Training Loss: 1.6640, Validation Loss: 0.8702
# Saved model with validation loss: 0.8702
# Epoch [17/50], Training Loss: 1.6369, Validation Loss: 0.9107
# Epoch [18/50], Training Loss: 1.6031, Validation Loss: 0.8844
# Epoch [19/50], Training Loss: 1.5743, Validation Loss: 0.8788
# Epoch [20/50], Training Loss: 1.5527, Validation Loss: 0.8388
# Saved model with validation loss: 0.8388
# Epoch [21/50], Training Loss: 1.5151, Validation Loss: 0.8576
# Epoch [22/50], Training Loss: 1.4940, Validation Loss: 0.8339
# Saved model with validation loss: 0.8339
# Epoch [23/50], Training Loss: 1.4638, Validation Loss: 0.8377
# Epoch [24/50], Training Loss: 1.4447, Validation Loss: 0.7946
# Saved model with validation loss: 0.7946
# Epoch [25/50], Training Loss: 1.4069, Validation Loss: 0.8509
# Epoch [26/50], Training Loss: 1.3887, Validation Loss: 0.8275
# Epoch [27/50], Training Loss: 1.3716, Validation Loss: 0.8143
# Epoch [28/50], Training Loss: 1.3331, Validation Loss: 0.8022
# Epoch [29/50], Training Loss: 1.3163, Validation Loss: 0.7728
# Saved model with validation loss: 0.7728
# Epoch [30/50], Training Loss: 1.2829, Validation Loss: 0.8203
# Epoch [31/50], Training Loss: 1.2554, Validation Loss: 0.7862
# Epoch [32/50], Training Loss: 1.2291, Validation Loss: 0.7819
# Epoch [33/50], Training Loss: 1.2172, Validation Loss: 0.7928
# Epoch [34/50], Training Loss: 1.1915, Validation Loss: 0.8077
# Epoch [35/50], Training Loss: 1.1621, Validation Loss: 0.8295
# Epoch [36/50], Training Loss: 1.1428, Validation Loss: 0.7940
# Epoch [37/50], Training Loss: 1.1231, Validation Loss: 0.7829
# Epoch [38/50], Training Loss: 1.0986, Validation Loss: 0.8141
# Epoch [39/50], Training Loss: 1.0784, Validation Loss: 0.7735
# Epoch [40/50], Training Loss: 1.0541, Validation Loss: 0.7997
# Epoch [41/50], Training Loss: 1.0280, Validation Loss: 0.8122
# Epoch [42/50], Training Loss: 1.0110, Validation Loss: 0.8048
# Epoch [43/50], Training Loss: 0.9946, Validation Loss: 0.8592
# Epoch [44/50], Training Loss: 0.9743, Validation Loss: 0.7901
# Epoch [45/50], Training Loss: 0.9449, Validation Loss: 0.8365
# Epoch [46/50], Training Loss: 0.9298, Validation Loss: 0.7925
# Epoch [47/50], Training Loss: 0.9076, Validation Loss: 0.8844
# Epoch [48/50], Training Loss: 0.8902, Validation Loss: 0.7969
# Epoch [49/50], Training Loss: 0.8722, Validation Loss: 0.8284
# Epoch [50/50], Training Loss: 0.8456, Validation Loss: 0.8541
# Model with hidden_size 256 and learning_rate 0.0003 achieved validation loss: 0.7728050053119659. Embedding dim: 50. num_hidden_layers: 1
# ===== Accuracy 0.4510.
# Training with hidden_size: 256, learning_rate: 0.0002
# Epoch [1/50], Training Loss: 3.3169, Validation Loss: 2.8939
# Saved model with validation loss: 2.8939
# Epoch [2/50], Training Loss: 2.7041, Validation Loss: 2.0258
# Saved model with validation loss: 2.0258
# Epoch [3/50], Training Loss: 2.4567, Validation Loss: 1.6969
# Saved model with validation loss: 1.6969
# Epoch [4/50], Training Loss: 2.3500, Validation Loss: 1.5759
# Saved model with validation loss: 1.5759
# Epoch [5/50], Training Loss: 2.2742, Validation Loss: 1.4440
# Saved model with validation loss: 1.4440
# Epoch [6/50], Training Loss: 2.2106, Validation Loss: 1.3343
# Saved model with validation loss: 1.3343
# Epoch [7/50], Training Loss: 2.1576, Validation Loss: 1.3088
# Saved model with validation loss: 1.3088
# Epoch [8/50], Training Loss: 2.1067, Validation Loss: 1.2208
# Saved model with validation loss: 1.2208
# Epoch [9/50], Training Loss: 2.0649, Validation Loss: 1.0963
# Saved model with validation loss: 1.0963
# Epoch [10/50], Training Loss: 2.0306, Validation Loss: 1.1126
# Epoch [11/50], Training Loss: 1.9911, Validation Loss: 1.1044
# Epoch [12/50], Training Loss: 1.9563, Validation Loss: 1.0694
# Saved model with validation loss: 1.0694
# Epoch [13/50], Training Loss: 1.9264, Validation Loss: 1.0438
# Saved model with validation loss: 1.0438
# Epoch [14/50], Training Loss: 1.8977, Validation Loss: 1.0998
# Epoch [15/50], Training Loss: 1.8738, Validation Loss: 1.0170
# Saved model with validation loss: 1.0170
# Epoch [16/50], Training Loss: 1.8413, Validation Loss: 0.9570
# Saved model with validation loss: 0.9570
# Epoch [17/50], Training Loss: 1.8196, Validation Loss: 0.9694
# Epoch [18/50], Training Loss: 1.7901, Validation Loss: 0.9611
# Epoch [19/50], Training Loss: 1.7695, Validation Loss: 0.9422
# Saved model with validation loss: 0.9422
# Epoch [20/50], Training Loss: 1.7400, Validation Loss: 0.9576
# Epoch [21/50], Training Loss: 1.7211, Validation Loss: 0.9022
# Saved model with validation loss: 0.9022
# Epoch [22/50], Training Loss: 1.7014, Validation Loss: 0.8847
# ...
# Epoch [10/50], Training Loss: 2.3988, Validation Loss: 1.8024
# Saved model with validation loss: 1.8024
# Epoch [11/50], Training Loss: 2.3695, Validation Loss: 1.7273
# Saved model with validation loss: 1.7273
# Epoch [12/50], Training Loss: 2.3383, Validation Loss: 1.6374
# Saved model with validation loss: 1.6374
# Epoch [13/50], Training Loss: 2.3108, Validation Loss: 1.6159
# Saved model with validation loss: 1.6159
# Epoch [14/50], Training Loss: 2.2843, Validation Loss: 1.5813
# Saved model with validation loss: 1.5813
# Epoch [15/50], Training Loss: 2.2589, Validation Loss: 1.5105
# Saved model with validation loss: 1.5105
# Epoch [16/50], Training Loss: 2.2286, Validation Loss: 1.4925
# Saved model with validation loss: 1.4925
# Epoch [17/50], Training Loss: 2.2061, Validation Loss: 1.4647
# Saved model with validation loss: 1.4647
# Epoch [18/50], Training Loss: 2.1810, Validation Loss: 1.4122
# Saved model with validation loss: 1.4122
# Epoch [19/50], Training Loss: 2.1619, Validation Loss: 1.3945
# Saved model with validation loss: 1.3945
# Epoch [20/50], Training Loss: 2.1336, Validation Loss: 1.3878
# Saved model with validation loss: 1.3878
# Epoch [21/50], Training Loss: 2.1139, Validation Loss: 1.3012
# Saved model with validation loss: 1.3012
# Epoch [22/50], Training Loss: 2.0911, Validation Loss: 1.3282
# Epoch [23/50], Training Loss: 2.0678, Validation Loss: 1.3149
# Epoch [24/50], Training Loss: 2.0500, Validation Loss: 1.3054
# Epoch [25/50], Training Loss: 2.0292, Validation Loss: 1.2635
# Saved model with validation loss: 1.2635
# Epoch [26/50], Training Loss: 1.9989, Validation Loss: 1.1895
# Saved model with validation loss: 1.1895
# Epoch [27/50], Training Loss: 1.9824, Validation Loss: 1.1378
# Saved model with validation loss: 1.1378
# Epoch [28/50], Training Loss: 1.9651, Validation Loss: 1.1959
# Epoch [29/50], Training Loss: 1.9451, Validation Loss: 1.1880
# Epoch [30/50], Training Loss: 1.9298, Validation Loss: 1.1096
# Saved model with validation loss: 1.1096
# Epoch [31/50], Training Loss: 1.8996, Validation Loss: 1.0876
# Saved model with validation loss: 1.0876
# Epoch [32/50], Training Loss: 1.8835, Validation Loss: 1.0643
# Saved model with validation loss: 1.0643
# Epoch [33/50], Training Loss: 1.8607, Validation Loss: 1.0973
# Epoch [34/50], Training Loss: 1.8411, Validation Loss: 1.0523
# Saved model with validation loss: 1.0523
# Epoch [35/50], Training Loss: 1.8257, Validation Loss: 1.0722
# Epoch [36/50], Training Loss: 1.8074, Validation Loss: 1.0474
# Saved model with validation loss: 1.0474
# Epoch [37/50], Training Loss: 1.7896, Validation Loss: 1.0123
# Saved model with validation loss: 1.0123
# Epoch [38/50], Training Loss: 1.7728, Validation Loss: 0.9877
# Saved model with validation loss: 0.9877
# Epoch [39/50], Training Loss: 1.7528, Validation Loss: 1.0327
# Epoch [40/50], Training Loss: 1.7361, Validation Loss: 1.0079
# Epoch [41/50], Training Loss: 1.7186, Validation Loss: 0.9797
# Saved model with validation loss: 0.9797
# Epoch [42/50], Training Loss: 1.7133, Validation Loss: 0.9483
# Saved model with validation loss: 0.9483
# Epoch [43/50], Training Loss: 1.6949, Validation Loss: 0.9895
# Epoch [44/50], Training Loss: 1.6738, Validation Loss: 0.9923
# Epoch [45/50], Training Loss: 1.6534, Validation Loss: 0.9273
# Saved model with validation loss: 0.9273
# Epoch [46/50], Training Loss: 1.6416, Validation Loss: 0.9253
# Saved model with validation loss: 0.9253
# Epoch [47/50], Training Loss: 1.6207, Validation Loss: 0.9300
# Epoch [48/50], Training Loss: 1.6073, Validation Loss: 0.9108
# Saved model with validation loss: 0.9108
# Epoch [49/50], Training Loss: 1.5874, Validation Loss: 0.9573
# Epoch [50/50], Training Loss: 1.5697, Validation Loss: 0.9588
# Model with hidden_size 128 and learning_rate 0.0002 achieved validation loss: 0.9108182688554128. Embedding dim: 50. num_hidden_layers: 3
# ===== Accuracy 0.4196.
# Training with hidden_size: 128, learning_rate: 0.0001
# Epoch [1/50], Training Loss: 3.4510, Validation Loss: 3.4315
# Saved model with validation loss: 3.4315
# Epoch [2/50], Training Loss: 3.2448, Validation Loss: 2.8603
# Saved model with validation loss: 2.8603
# Epoch [3/50], Training Loss: 2.8118, Validation Loss: 2.5026
# Saved model with validation loss: 2.5026
# Epoch [4/50], Training Loss: 2.7238, Validation Loss: 2.4161
# Saved model with validation loss: 2.4161
# Epoch [5/50], Training Loss: 2.6909, Validation Loss: 2.3473
# Saved model with validation loss: 2.3473
# Epoch [6/50], Training Loss: 2.6633, Validation Loss: 2.3507
# Epoch [7/50], Training Loss: 2.6378, Validation Loss: 2.3071
# Saved model with validation loss: 2.3071
# Epoch [8/50], Training Loss: 2.6127, Validation Loss: 2.2389
# Saved model with validation loss: 2.2389
# Epoch [9/50], Training Loss: 2.5824, Validation Loss: 2.1896
# Saved model with validation loss: 2.1896
# Epoch [10/50], Training Loss: 2.5516, Validation Loss: 2.1244
# Saved model with validation loss: 2.1244
# Epoch [11/50], Training Loss: 2.5254, Validation Loss: 2.0795
# Saved model with validation loss: 2.0795
# Epoch [12/50], Training Loss: 2.4951, Validation Loss: 2.0160
# Saved model with validation loss: 2.0160
# Epoch [13/50], Training Loss: 2.4760, Validation Loss: 1.9941
# Saved model with validation loss: 1.9941
# Epoch [14/50], Training Loss: 2.4529, Validation Loss: 1.9319
# Saved model with validation loss: 1.9319
# Epoch [15/50], Training Loss: 2.4341, Validation Loss: 1.8848
# Saved model with validation loss: 1.8848
# Epoch [16/50], Training Loss: 2.4134, Validation Loss: 1.8498
# Saved model with validation loss: 1.8498
# Epoch [17/50], Training Loss: 2.3953, Validation Loss: 1.8199
# Saved model with validation loss: 1.8199
# Epoch [18/50], Training Loss: 2.3772, Validation Loss: 1.7895
# Saved model with validation loss: 1.7895
# Epoch [19/50], Training Loss: 2.3585, Validation Loss: 1.7645
# Saved model with validation loss: 1.7645
# Epoch [20/50], Training Loss: 2.3422, Validation Loss: 1.7273
# Saved model with validation loss: 1.7273
# Epoch [21/50], Training Loss: 2.3254, Validation Loss: 1.7056
# Saved model with validation loss: 1.7056
# Epoch [22/50], Training Loss: 2.3120, Validation Loss: 1.6701
# Saved model with validation loss: 1.6701
# Epoch [23/50], Training Loss: 2.2976, Validation Loss: 1.6604
# Saved model with validation loss: 1.6604
# Epoch [24/50], Training Loss: 2.2832, Validation Loss: 1.6283
# Saved model with validation loss: 1.6283
# Epoch [25/50], Training Loss: 2.2648, Validation Loss: 1.6332
# Epoch [26/50], Training Loss: 2.2548, Validation Loss: 1.5799
# Saved model with validation loss: 1.5799
# Epoch [27/50], Training Loss: 2.2401, Validation Loss: 1.5566
# Saved model with validation loss: 1.5566
# Epoch [28/50], Training Loss: 2.2251, Validation Loss: 1.5746
# Epoch [29/50], Training Loss: 2.2156, Validation Loss: 1.5457
# Saved model with validation loss: 1.5457
# Epoch [30/50], Training Loss: 2.2026, Validation Loss: 1.5127
# Saved model with validation loss: 1.5127
# Epoch [31/50], Training Loss: 2.1965, Validation Loss: 1.5511
# Epoch [32/50], Training Loss: 2.1783, Validation Loss: 1.4890
# Saved model with validation loss: 1.4890
# Epoch [33/50], Training Loss: 2.1709, Validation Loss: 1.4733
# Saved model with validation loss: 1.4733
# Epoch [34/50], Training Loss: 2.1542, Validation Loss: 1.4741
# Epoch [35/50], Training Loss: 2.1444, Validation Loss: 1.4561
# Saved model with validation loss: 1.4561
# Epoch [36/50], Training Loss: 2.1351, Validation Loss: 1.4492
# Saved model with validation loss: 1.4492
# Epoch [37/50], Training Loss: 2.1226, Validation Loss: 1.3962
# Saved model with validation loss: 1.3962
# Epoch [38/50], Training Loss: 2.1100, Validation Loss: 1.3876
# Saved model with validation loss: 1.3876
# Epoch [39/50], Training Loss: 2.1031, Validation Loss: 1.3947
# Epoch [40/50], Training Loss: 2.0931, Validation Loss: 1.3880
# Epoch [41/50], Training Loss: 2.0827, Validation Loss: 1.3343
# Saved model with validation loss: 1.3343
# Epoch [42/50], Training Loss: 2.0682, Validation Loss: 1.3536
# Epoch [43/50], Training Loss: 2.0595, Validation Loss: 1.3374
# Epoch [44/50], Training Loss: 2.0490, Validation Loss: 1.3248
# Saved model with validation loss: 1.3248
# Epoch [45/50], Training Loss: 2.0411, Validation Loss: 1.3592
# Epoch [46/50], Training Loss: 2.0300, Validation Loss: 1.3069
# Saved model with validation loss: 1.3069
# Epoch [47/50], Training Loss: 2.0200, Validation Loss: 1.3129
# Epoch [48/50], Training Loss: 2.0123, Validation Loss: 1.2906
# Saved model with validation loss: 1.2906
# Epoch [49/50], Training Loss: 2.0033, Validation Loss: 1.2894
# Saved model with validation loss: 1.2894
# Epoch [50/50], Training Loss: 1.9937, Validation Loss: 1.2782
# Saved model with validation loss: 1.2782
# Model with hidden_size 128 and learning_rate 0.0001 achieved validation loss: 1.278227945168813. Embedding dim: 50. num_hidden_layers: 3
# ===== Accuracy 0.3373.
# Training with hidden_size: 256, learning_rate: 0.0003
# Epoch [1/50], Training Loss: 3.0968, Validation Loss: 2.4085
# Saved model with validation loss: 2.4085
# Epoch [2/50], Training Loss: 2.6785, Validation Loss: 2.2502
# Saved model with validation loss: 2.2502
# Epoch [3/50], Training Loss: 2.5745, Validation Loss: 2.0216
# Saved model with validation loss: 2.0216
# Epoch [4/50], Training Loss: 2.4912, Validation Loss: 1.7725
# Saved model with validation loss: 1.7725
# Epoch [5/50], Training Loss: 2.4096, Validation Loss: 1.8211
# Epoch [6/50], Training Loss: 2.3409, Validation Loss: 1.7668
# Saved model with validation loss: 1.7668
# Epoch [7/50], Training Loss: 2.2787, Validation Loss: 1.5141
# Saved model with validation loss: 1.5141
# Epoch [8/50], Training Loss: 2.2134, Validation Loss: 1.4057
# Saved model with validation loss: 1.4057
# Epoch [9/50], Training Loss: 2.1469, Validation Loss: 1.3724
# Saved model with validation loss: 1.3724
# Epoch [10/50], Training Loss: 2.0898, Validation Loss: 1.2436
# Saved model with validation loss: 1.2436
# Epoch [11/50], Training Loss: 2.0325, Validation Loss: 1.1438
# Saved model with validation loss: 1.1438
# Epoch [12/50], Training Loss: 1.9760, Validation Loss: 1.1697
# Epoch [13/50], Training Loss: 1.9302, Validation Loss: 1.0746
# Saved model with validation loss: 1.0746
# Epoch [14/50], Training Loss: 1.8700, Validation Loss: 0.9585
# Saved model with validation loss: 0.9585
# Epoch [15/50], Training Loss: 1.8270, Validation Loss: 0.9720
# Epoch [16/50], Training Loss: 1.7731, Validation Loss: 1.0249
# Epoch [17/50], Training Loss: 1.7209, Validation Loss: 0.9664
# Epoch [18/50], Training Loss: 1.6843, Validation Loss: 1.0139
# Epoch [19/50], Training Loss: 1.6551, Validation Loss: 0.9203
# Saved model with validation loss: 0.9203
# Epoch [20/50], Training Loss: 1.6099, Validation Loss: 0.8866
# Saved model with validation loss: 0.8866
# Epoch [21/50], Training Loss: 1.5634, Validation Loss: 0.8240
# Saved model with validation loss: 0.8240
# Epoch [22/50], Training Loss: 1.5337, Validation Loss: 0.8261
# Epoch [23/50], Training Loss: 1.4833, Validation Loss: 0.8648
# Epoch [24/50], Training Loss: 1.4578, Validation Loss: 0.8132
# Saved model with validation loss: 0.8132
# Epoch [25/50], Training Loss: 1.4148, Validation Loss: 0.8760
# Epoch [26/50], Training Loss: 1.3935, Validation Loss: 0.9219
# Epoch [27/50], Training Loss: 1.3487, Validation Loss: 0.8198
# Epoch [28/50], Training Loss: 1.3175, Validation Loss: 0.8771
# Epoch [29/50], Training Loss: 1.2672, Validation Loss: 0.8671
# Epoch [30/50], Training Loss: 1.2438, Validation Loss: 0.7837
# Saved model with validation loss: 0.7837
# Epoch [31/50], Training Loss: 1.1988, Validation Loss: 0.8258
# Epoch [32/50], Training Loss: 1.1745, Validation Loss: 0.9079
# Epoch [33/50], Training Loss: 1.1366, Validation Loss: 0.8347
# Epoch [34/50], Training Loss: 1.1036, Validation Loss: 0.7908
# Epoch [35/50], Training Loss: 1.0787, Validation Loss: 0.8568
# Epoch [36/50], Training Loss: 1.0330, Validation Loss: 0.8624
# Epoch [37/50], Training Loss: 1.0016, Validation Loss: 0.8730
# Epoch [38/50], Training Loss: 0.9707, Validation Loss: 0.8636
# Epoch [39/50], Training Loss: 0.9392, Validation Loss: 0.9414
# Epoch [40/50], Training Loss: 0.9113, Validation Loss: 0.8709
# Epoch [41/50], Training Loss: 0.8899, Validation Loss: 0.8816
# Epoch [42/50], Training Loss: 0.8546, Validation Loss: 0.9098
# Epoch [43/50], Training Loss: 0.8234, Validation Loss: 0.8208
# Epoch [44/50], Training Loss: 0.7975, Validation Loss: 0.9001
# Epoch [45/50], Training Loss: 0.7829, Validation Loss: 0.8967
# Epoch [46/50], Training Loss: 0.7514, Validation Loss: 0.9345
# Epoch [47/50], Training Loss: 0.7305, Validation Loss: 0.8801
# Epoch [48/50], Training Loss: 0.6941, Validation Loss: 0.9873
# Epoch [49/50], Training Loss: 0.6871, Validation Loss: 0.9767
# Epoch [50/50], Training Loss: 0.6572, Validation Loss: 0.9659
# Model with hidden_size 256 and learning_rate 0.0003 achieved validation loss: 0.7836521565914154. Embedding dim: 50. num_hidden_layers: 3
# ===== Accuracy 0.4549.
# Training with hidden_size: 256, learning_rate: 0.0002
# Epoch [1/50], Training Loss: 3.2350, Validation Loss: 2.5086
# Saved model with validation loss: 2.5086
# Epoch [2/50], Training Loss: 2.7139, Validation Loss: 2.3916
# Saved model with validation loss: 2.3916
# Epoch [3/50], Training Loss: 2.6278, Validation Loss: 2.1473
# Saved model with validation loss: 2.1473
# Epoch [4/50], Training Loss: 2.5452, Validation Loss: 2.0411
# Saved model with validation loss: 2.0411
# Epoch [5/50], Training Loss: 2.4911, Validation Loss: 1.8972
# Saved model with validation loss: 1.8972
# Epoch [6/50], Training Loss: 2.4373, Validation Loss: 1.8326
# Saved model with validation loss: 1.8326
# Epoch [7/50], Training Loss: 2.3905, Validation Loss: 1.7187
# Saved model with validation loss: 1.7187
# Epoch [8/50], Training Loss: 2.3511, Validation Loss: 1.6801
# Saved model with validation loss: 1.6801
# Epoch [9/50], Training Loss: 2.3009, Validation Loss: 1.6054
# Saved model with validation loss: 1.6054
# Epoch [10/50], Training Loss: 2.2384, Validation Loss: 1.4988
# Saved model with validation loss: 1.4988
# Epoch [11/50], Training Loss: 2.1942, Validation Loss: 1.3851
# Saved model with validation loss: 1.3851
# Epoch [12/50], Training Loss: 2.1411, Validation Loss: 1.2746
# Saved model with validation loss: 1.2746
# Epoch [13/50], Training Loss: 2.0970, Validation Loss: 1.2794
# Epoch [14/50], Training Loss: 2.0366, Validation Loss: 1.1925
# Saved model with validation loss: 1.1925
# Epoch [15/50], Training Loss: 1.9988, Validation Loss: 1.1937
# Epoch [16/50], Training Loss: 1.9649, Validation Loss: 1.1760
# Saved model with validation loss: 1.1760
# Epoch [17/50], Training Loss: 1.9194, Validation Loss: 1.1061
# Saved model with validation loss: 1.1061
# Epoch [18/50], Training Loss: 1.8728, Validation Loss: 1.0710
# Saved model with validation loss: 1.0710
# Epoch [19/50], Training Loss: 1.8393, Validation Loss: 1.0385
# Saved model with validation loss: 1.0385
# Epoch [20/50], Training Loss: 1.8040, Validation Loss: 1.0077
# Saved model with validation loss: 1.0077
# Epoch [21/50], Training Loss: 1.7666, Validation Loss: 0.9626
# Saved model with validation loss: 0.9626
# Epoch [22/50], Training Loss: 1.7445, Validation Loss: 1.0685
# Epoch [23/50], Training Loss: 1.7048, Validation Loss: 0.9513
# Saved model with validation loss: 0.9513
# Epoch [24/50], Training Loss: 1.6791, Validation Loss: 0.9624
# Epoch [25/50], Training Loss: 1.6573, Validation Loss: 0.9183
# Saved model with validation loss: 0.9183
# Epoch [26/50], Training Loss: 1.6256, Validation Loss: 0.9648
# Epoch [27/50], Training Loss: 1.5886, Validation Loss: 0.9724
# Epoch [28/50], Training Loss: 1.5635, Validation Loss: 0.8434
# Saved model with validation loss: 0.8434
# Epoch [29/50], Training Loss: 1.5396, Validation Loss: 0.8607
# Epoch [30/50], Training Loss: 1.5110, Validation Loss: 0.8224
# Saved model with validation loss: 0.8224
# Epoch [31/50], Training Loss: 1.4798, Validation Loss: 0.8002
# Saved model with validation loss: 0.8002
# Epoch [32/50], Training Loss: 1.4680, Validation Loss: 0.8061
# Epoch [33/50], Training Loss: 1.4343, Validation Loss: 0.8446
# Epoch [34/50], Training Loss: 1.4134, Validation Loss: 0.8012
# Epoch [35/50], Training Loss: 1.3904, Validation Loss: 0.8411
# Epoch [36/50], Training Loss: 1.3587, Validation Loss: 0.8296

# %%
# Assuming 'model' is your trained SimpleRNN model
predictions, actuals = predict(best_model, test_loader)

# Print the classification report
print(classification_report(actuals, predictions, target_names=[id2char[s] for s in set(actuals + predictions)]))

# Calculate and print the accuracy
accuracy = accuracy_score(actuals, predictions)
print(f"Accuracy: {accuracy:.4f}")

# %%
best_val_loss = float('inf')
best_model_hyperparams = {}
best_model = None

for num_hidden_layers in num_hidden_layers_list:
    for embedding_dim in embedding_dims:
        for hidden_size in hidden_sizes:
            for lr in learning_rates:
                print(f"Training with hidden_size: {hidden_size}, learning_rate: {lr}, embedding_dim: {embedding_dim}, num_hidden_layers: {num_hidden_layers}")
                
                model_save_path = f"model_hs{hidden_size}_lr{lr}_ed{embedding_dim}_nhl{num_hidden_layers}.pth"
                model, val_loss = create_and_train_model(input_size, hidden_size, output_size, num_hidden_layers, embedding_dim, train_loader, val_loader, lr, num_epochs, model_save_path)
                
                print(f"Validation Loss: {val_loss}")
                
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    best_model = model
                    best_model_hyperparams = {'hidden_size': hidden_size, 'learning_rate': lr, 'embedding_dim': embedding_dim, 'num_hidden_layers': num_hidden_layers}
                    # Optionally, save the best model
                    torch.save(best_model.state_dict(), model_save_path)
                    predictions, actuals = predict(model, val_loader)
                    
                    # Calculate and print the accuracy
                    accuracy = accuracy_score(actuals, predictions)
                    print(f"===== Accuracy {accuracy:.4f}.")

print(f"Best Model Hyperparameters: {best_model_hyperparams}, Lowest Validation Loss: {best_val_loss}")

# %%
# Assuming 'model' is your trained SimpleRNN model
predictions, actuals = predict(best_model, test_loader)

# Print the classification report
print(classification_report(actuals, predictions, target_names=[id2char[s] for s in set(actuals + predictions)]))

# Calculate and print the accuracy
accuracy = accuracy_score(actuals, predictions)
print(f"Accuracy: {accuracy:.4f}")
